# %%
import os
import json
import pandas as pd


--use_peft --use_int4 --learning_rate 2e-4 --train_batch_size 12 --num_train_epochs 2

# %%
def generate_prompt(label):
    if label== 1:
        return "Teniendo en cuenta que el usuario está deprimido, justifica los motivos de esto con base en sus publicaciones"
    elif label==0:
        return "Teniendo en cuenta que el usuario no está deprimido, justifica los motivos de esto con base en sus publicaciones"
    elif label==-1:
        return "Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no"

# %%
def process_mentalrisk_data():
    users_dirs = ["MentalRisk/subjects_train", "MentalRisk/subjects_trial"]
    usuarios = []

    # Read All User Data
    for dir in users_dirs:
        user_files = [os.path.join(dir,file) for file in os.listdir(dir)]
        
        for user_file in user_files:
            filename,filext = os.path.splitext(user_file)
            
            with open(user_file,"r") as f:
                content=f.read()
                user=json.loads(content)
                usuarios.append({"username" : filename.split("/")[-1], "posts" : user})


    # Read All Labels to generate prompt
    train_labels = pd.read_csv("MentalRisk/gold_train_task2a.csv")
    trial_labels = pd.read_csv("MentalRisk/gold_trial_task2a.csv")
    labels = pd.concat([train_labels,trial_labels])
    labels.set_index("Subject",inplace=True)
    finallabels = labels.to_dict(orient='index')

    # Transform Data into a new format
    final_users = []

    for i,user in enumerate(usuarios):
        label = finallabels[user["username"]]["label"]
        prompt = generate_prompt(label)

        user_template = {
            "username": user["username"],
            "depressed": label,
            "response": "",
            "posts": [],
            "prompt" : prompt
        }
        
        for j,post in enumerate(user["posts"]):
            user_template["posts"].append({
                "id": j,
                "text": post["message"],
                "image_path": "None",
                "image_description": "None"
            })

        final_users.append(user_template)
            
    return final_users

# %%
import shutil


def process_reddit_data():
    root_dir = "Reddit/Users"
    users_dir = os.listdir(root_dir)
    text_extension = ['.txt']
    image_extensions = ['.jpg', '.jpeg', '.png', '.gif', '.bmp', '.tiff', '.webp']


    users_data = []

    
    for user_dir in users_dir:
        posts_files=os.listdir(os.path.join(root_dir,user_dir))

        user_template = {
            "username": f"{user_dir}",
            "depressed": -1,
            "response": "",
            "posts": [],
            "prompt" : generate_prompt(-1)
        }

        for j in range(len(posts_files)):
            # Obtiene el texto de la publicación
            post_metadata = os.path.splitext(posts_files[j])[0].split("_")
            text = post_metadata[3:]
            text = " ".join(text)
            
            # Comprueba si es imagen o texto
            file_extension = os.path.splitext(posts_files[j])[1].lower()
            
            if file_extension in text_extension:
                image_path = "None"
            elif file_extension in image_extensions:
                image_path = posts_files[j]
                shutil.move(os.path.join(root_dir,user_dir,posts_files[j]),"UserImages")
            
            # Añade la publicación a la lista
            user_template["posts"].append({
                "id": j,
                "text": text,
                "image_path": image_path,
                "image_description": "None"
            })
            
        users_data.append(user_template)

    return users_data

reddit_data = process_reddit_data()
reddit_data
# Out:
# [{'username': 'Healthy-Decision-157',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'i feel like im misdiagnosed',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'can i be depressed and still feel happy for the',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 2,
#     'text': 'achievements missing',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'max',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'eon2pn a lot of people ask me how i got this username',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'in 1971 the cia published an atlas of china 01',
#     'image_path': '2024-03-13_pics_1be38sv_in_1971_the_cia_published_an_atlas_of_china_01.jpg',
#     'image_description': 'None'},
#    {'id': 2,
#     'text': 'in 1971 the cia published an atlas of china 02',
#     'image_path': '2024-03-13_pics_1be38sv_in_1971_the_cia_published_an_atlas_of_china_02.jpg',
#     'image_description': 'None'},
#    {'id': 3,
#     'text': 'bird',
#     'image_path': '2024-07-24_pics_1eaz3nn_bird.jpg',
#     'image_description': 'None'},
#    {'id': 4,
#     'text': '',
#     'image_path': 'ctgNsBJnk0Lc1M-yclUun39ju-a2qE6EJtDUaW4DOsI.png',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'Able-Anywhere4736',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'i cant live with my thoughts',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'Appropriate',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'introducing a vibrator into the bedroom',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'BINGOBONGO3333333',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'no instagram post for 30th anniversary of',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'what would be a good alternative symbol for',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 2,
#     'text': 'what religion most closely reflects the ideas of',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 3,
#     'text': 'what economic system did conservatives favor',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 4,
#     'text': 'was soft rock considered rock in the 70s',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 5,
#     'text': 'was rock n roll just mkuktra for the masses',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 6,
#     'text': 'isnt the hammer and sickle an ironic symbol for',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 7,
#     'text': 'phils wife is responsible for vitos death',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 8,
#     'text': 'i want to be christian but dont agree with all of',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 9,
#     'text': 'the new republic being demilitarized makes no',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'buggycruise',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'found out our rental home was covered in mold',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'Camillionaire94',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'how do i tell someone that i politely dont want',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'ill never be normal',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 2,
#     'text': 'spqlnv should i be as upset as i am my fiance lied about',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 3,
#     'text': 'so i relapsed',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 4,
#     'text': 'i left my fiance and ive almost entirely stopped',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 5,
#     'text': 'i thought it would be okay',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 6,
#     'text': 'im tired',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 7,
#     'text': 'im tired',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 8,
#     'text': 'what is your best i just noticed that moment',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 9,
#     'text': 'dani is not actually blond',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 10,
#     'text': 'anyone else think they were a bit over the top',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 11,
#     'text': 'i dont know if i should just go back to drinking',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 12,
#     'text': 'that moment you realize you could go missing and',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 13,
#     'text': 'do i have depression or am i actually just lazy',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 14,
#     'text': 'so there is hope',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 15,
#     'text': 'do you see the potential too',
#     'image_path': '2024-07-27_Midsommar_1edkn7n_do_you_see_the_potential_too.jpg',
#     'image_description': 'None'},
#    {'id': 16,
#     'text': 'do you see the potential too',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'CapitalFlounder8699',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'reference',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'paladin strait is the best song twenty one pilots',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 2,
#     'text': 'overall worst twenty one pilots song',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 3,
#     'text': 'how do i enchant items mobs are holding in the',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'Cerberus-Coco-Mimi',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'obesssion with machismoism',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'how to maintain a healthy relationship',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'chloeanneelizabeth',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'what to eat when elvanse kills your appetite',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'pre loan of 150 prearranged with lender',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 2,
#     'text': 'i suck at keeping friends',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 3,
#     'text': 'does going down rtc still keep your nhs referral',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 4,
#     'text': '25nb uk i suck at making friends but i really do',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 5,
#     'text': 'dae have meltdowns in their dreams',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 6,
#     'text': 'pre loan of 250 prearranged with lender',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 7,
#     'text': 'giving away 50',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 8,
#     'text': 'preloan of 750 cad prearranged with lender',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 9,
#     'text': 'dae on adhd meds sweat all the time',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 10,
#     'text': 'why do i feel so bad all the time',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 11,
#     'text': 'for the first time in a very long time the urges',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 12,
#     'text': 'requesting 60 for medication',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 13,
#     'text': 'best earplugs for concerts',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 14,
#     'text': 'shared care agreement timeline',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 15,
#     'text': 'gave benefit of the doubt silly me',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 16,
#     'text': 'i feel very strange tonight',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'Cool-Dependent9518',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'looking for committed minecraft players',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'advice',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 2,
#     'text': 'becoming distracted',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 3,
#     'text': 'feeling lost',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'CulturalSquare1835',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'anxietydepression',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'depression',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 2,
#     'text': 'cashapp blessings',
#     'image_path': '2023-11-01_CashApp_17llfg3_cashapp_blessings.jpg',
#     'image_description': 'None'},
#    {'id': 3,
#     'text': 'sow a seed',
#     'image_path': '2023-11-01_CashApp_17llihx_sow_a_seed.jpg',
#     'image_description': 'None'},
#    {'id': 4,
#     'text': 'prozac',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 5,
#     'text': 'rants',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 6,
#     'text': 'oh boy',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 7,
#     'text': 'chin up chest out',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 8,
#     'text': 'depression',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 9,
#     'text': 'cuttingdepression',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'Daldric',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'how to win against weird strat created in vacuum',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'i suck as rogue and i dont really know how to get',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 2,
#     'text': 'can someone tell me whats wrong with my deck',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 3,
#     'text': 'what is the most insidious cologne i can wear',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 4,
#     'text': 'ive never watched a single episode of digimon and',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 5,
#     'text': 'trying to make an edh deck with alrund god of the',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 6,
#     'text': 'imo slaughterhouse 2 is the worst song on you',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 7,
#     'text': 'relaxing music for a metal head',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 8,
#     'text': '',
#     'image_path': '2aDD-yv8of0RTs-UW9ZBPpNkuWsqem-SUjQKrF-iiQQ.jpg',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'darthjimim',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'more changes',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'thoughts on the betrayal',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 2,
#     'text': 'watching the doc',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 3,
#     'text': 'my ratings of s1',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 4,
#     'text': 'i dont know what to do anymore',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 5,
#     'text': 'season 2 renewal',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 6,
#     'text': 'nonfan first thoughts',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 7,
#     'text': 'lunch break as minor',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 8,
#     'text': 'about stocking',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 9,
#     'text': 'adhd and belts',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 10,
#     'text': 'dont look at me like that',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 11,
#     'text': 'haha nice',
#     'image_path': '2024-05-06_WalmartEmployees_1clm0wj_haha_nice.jpg',
#     'image_description': 'None'},
#    {'id': 12,
#     'text': 'i just want to live in my dreams',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 13,
#     'text': 'question abt discount card',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'Defiant-One7064',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'this is the nature of the depressed person',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'Desperate-Prompt5003',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'ive lost all will to live 18m',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': '18 dead soon',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 2,
#     'text': 'ive been trapped in my old self and im going to',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 3,
#     'text': 'are the lines between attention seeking and',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 4,
#     'text': '1ec3mhp w steal',
#     'image_path': '2024-07-25_R6Marketplace_Trading_1ec3mhp_w_steal.png',
#     'image_description': 'None'},
#    {'id': 5,
#     'text': 'i wonder if this planet would have some cool lore',
#     'image_path': '2024-07-31_NoMansSkyTheGame_1egih5j_i_wonder_if_this_planet_would_have_some_cool_lore.jpg',
#     'image_description': 'None'},
#    {'id': 6,
#     'text': 'where do yall think juice would be if it included',
#     'image_path': '2024-08-02_JuiceWRLD_1ei9pv5_where_do_yall_think_juice_would_be_if_it_included.jpg',
#     'image_description': 'None'},
#    {'id': 7,
#     'text': 'pov moon',
#     'image_path': '2024-08-02_NoMansSkyTheGame_1eif5k9_pov_moon.jpg',
#     'image_description': 'None'},
#    {'id': 8,
#     'text': 'the colours are so cool',
#     'image_path': '2024-08-04_NoMansSkyTheGame_1ejx9rh_the_colours_are_so_cool.jpg',
#     'image_description': 'None'},
#    {'id': 9,
#     'text': 'i was screaming and shouting a lot hahahaha',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 10,
#     'text': 'appreciation post this song is so fire',
#     'image_path': '2024-08-10_JuiceWRLD_1ep5j19_appreciation_post_this_song_is_so_fire.png',
#     'image_description': 'None'},
#    {'id': 11,
#     'text': 'suffering and doing nothing is much worse than',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 12,
#     'text': 'i took 8 codeine pills before my gcse english exam',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 13,
#     'text': 'grandview finally put the absolutely nothing ep',
#     'image_path': '2024-08-29_Emo_1f3znix_grandview_finally_put_the_absolutely_nothing_ep.png',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'dylan212121',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'o17a24 no one will see this but if you do',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'i just want eliteadvanced ranger armor',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 2,
#     'text': 'minifig packs and ashoka brickhead',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 3,
#     'text': 'im officially alone now',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 4,
#     'text': 'love the shipment',
#     'image_path': '2022-04-26_lululemon_ucrbcz_love_the_shipment.jpg',
#     'image_description': 'None'},
#    {'id': 5,
#     'text': 'love the shipments my store gets',
#     'image_path': '2022-05-14_lululemon_upp2u4_love_the_shipments_my_store_gets.jpg',
#     'image_description': 'None'},
#    {'id': 6,
#     'text': 'i finally put them on a shelf and im so happy',
#     'image_path': '2022-05-16_starwarscollecting_ur7erb_i_finally_put_them_on_a_shelf_and_im_so_happy.jpg',
#     'image_description': 'None'},
#    {'id': 7,
#     'text': '22pstpc',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 8,
#     'text': 'failure',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 9,
#     'text': 'i feel so pressured',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 10,
#     'text': 'i wish i was smart like everyone else',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 11,
#     'text': 'anyone know if i can get this anywhere',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 12,
#     'text': 'anyone know if i can get this anywhere 01',
#     'image_path': '2024-07-05_FashionReps_1dwd8yd_anyone_know_if_i_can_get_this_anywhere_01.jpg',
#     'image_description': 'None'},
#    {'id': 13,
#     'text': 'anyone know if i can get this anywhere 02',
#     'image_path': '2024-07-05_FashionReps_1dwd8yd_anyone_know_if_i_can_get_this_anywhere_02.jpg',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'Gibemeit',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'it has been 3 years since ive dated a sex',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'it has been 3 years since ive dated a sex',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'glorytoad',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'chewie and bb8 that my sil made at long last',
#     'image_path': '2019-12-25_StarWars_efmnl9_chewie_and_bb8_that_my_sil_made_at_long_last.jpg',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'trade questions',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 2,
#     'text': 'im so tired of being depressed',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 3,
#     'text': 'i like being honorable',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 4,
#     'text': 'store walk time',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 5,
#     'text': 'screwed me over and screwed over my vacation',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 6,
#     'text': 'so i just found this sub should have found it 18',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 7,
#     'text': 'im on day three',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 8,
#     'text': 'homework balance my ass',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 9,
#     'text': 'my sister in law made these for my little girl',
#     'image_path': '2019-09-24_StarWars_d8wczv_my_sister_in_law_made_these_for_my_little_girl.jpg',
#     'image_description': 'None'},
#    {'id': 10,
#     'text': 'help out an idiot with something',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 11,
#     'text': 'vacation ignored',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 12,
#     'text': 'concerned about the virus and krogers response to',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 13,
#     'text': 'looking for advice',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 14,
#     'text': 'crab legs and steaming',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 15,
#     'text': 'meat tray shortage',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 16,
#     'text': 'a fine start to a day in the meat dept',
#     'image_path': '2020-08-27_kroger_ihpg5k_a_fine_start_to_a_day_in_the_meat_dept.jpg',
#     'image_description': 'None'},
#    {'id': 17,
#     'text': 'story time',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 18,
#     'text': 'insurance cards',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 19,
#     'text': 'well sht here we go again',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 20,
#     'text': 'im almost out of patience',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 21,
#     'text': 'just applied for meat cutter position in',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 22,
#     'text': 'not steaming anymore for anybody',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 23,
#     'text': 'the whole purpose of my life is over im just too',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 24,
#     'text': 'wife told me her sims were in a suicide cult and',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 25,
#     'text': 'wife told me her sims were in a suicide cult and 0001',
#     'image_path': '2024-06-24_Sims4_1dnuulw_wife_told_me_her_sims_were_in_a_suicide_cult_and_0001.jpg',
#     'image_description': 'None'},
#    {'id': 26,
#     'text': 'wife told me her sims were in a suicide cult and 0002',
#     'image_path': '2024-06-24_Sims4_1dnuulw_wife_told_me_her_sims_were_in_a_suicide_cult_and_0002.jpg',
#     'image_description': 'None'},
#    {'id': 27,
#     'text': 'wife told me her sims were in a suicide cult and 0003',
#     'image_path': '2024-06-24_Sims4_1dnuulw_wife_told_me_her_sims_were_in_a_suicide_cult_and_0003.jpg',
#     'image_description': 'None'},
#    {'id': 28,
#     'text': 'wife told me her sims were in a suicide cult and 0004',
#     'image_path': '2024-06-24_Sims4_1dnuulw_wife_told_me_her_sims_were_in_a_suicide_cult_and_0004.jpg',
#     'image_description': 'None'},
#    {'id': 29,
#     'text': 'my therapist canceled on me',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'HighCuda29',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': '1cxgmqe wifes a bit confusedor just selfish life hurts',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'honeypie1601',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'doing things is so overwhelming',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'the dwarf wont sell the rarecrow or talk to me',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'Horror-Performance87',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'help',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'psychosis',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 2,
#     'text': 'medication and diagnosis',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 3,
#     'text': 'how to deal with family rejection',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'human-in-headlights',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'feel so ignorant because of sa',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'bdc score under 5',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 2,
#     'text': 'cough impulse',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'I-Has-A-Sandwich',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'i dont understand why i cant seem to do this',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'Imfuckupmylife',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'im not okay',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'im still not okay',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 2,
#     'text': 'seriously',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 3,
#     'text': 'when you fight with your partner',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 4,
#     'text': 'struggle',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 5,
#     'text': 'انا مش كويس',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'Inevitable-Tone8469',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'trying to stay sane',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'Inner-Log-9901',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'i wouldve been raped if my father wasnt awake at',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'help me identify my gfs dog 001',
#     'image_path': '2023-08-16_dogbreed_15t79pe_help_me_identify_my_gfs_dog_001.jpg',
#     'image_description': 'None'},
#    {'id': 2,
#     'text': 'help me identify my gfs dog 002',
#     'image_path': '2023-08-16_dogbreed_15t79pe_help_me_identify_my_gfs_dog_002.jpg',
#     'image_description': 'None'},
#    {'id': 3,
#     'text': 'help me identify my gfs dog 003',
#     'image_path': '2023-08-16_dogbreed_15t79pe_help_me_identify_my_gfs_dog_003.jpg',
#     'image_description': 'None'},
#    {'id': 4,
#     'text': 'i wish life was easier',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 5,
#     'text': 'outside cat had kittens and we cant find them',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 6,
#     'text': 'why wont it let me buy this',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'InsaneCakes101',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'took some photos in a park',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'i hate myself',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 2,
#     'text': 'do i deserve to not exist',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 3,
#     'text': 'im a terrible person i deserve to be alone forever',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 4,
#     'text': 'i feel like i cant live life',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 5,
#     'text': 'any advice to make my relationship better',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 6,
#     'text': 'is my friend okay',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 7,
#     'text': 'do yall want a relationship like this or already',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 8,
#     'text': 'idk wtf is my purpose in life',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 9,
#     'text': 'should i make a run from my parents ill be back',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 10,
#     'text': 'took some photos in a park 0001',
#     'image_path': '2024-07-14_florida_1e3gx4a_took_some_photos_in_a_park_0001.jpg',
#     'image_description': 'None'},
#    {'id': 11,
#     'text': 'took some photos in a park 0002',
#     'image_path': '2024-07-14_florida_1e3gx4a_took_some_photos_in_a_park_0002.jpg',
#     'image_description': 'None'},
#    {'id': 12,
#     'text': 'took some photos in a park 0003',
#     'image_path': '2024-07-14_florida_1e3gx4a_took_some_photos_in_a_park_0003.jpg',
#     'image_description': 'None'},
#    {'id': 13,
#     'text': 'took some photos in a park 0004',
#     'image_path': '2024-07-14_florida_1e3gx4a_took_some_photos_in_a_park_0004.jpg',
#     'image_description': 'None'},
#    {'id': 14,
#     'text': 'what should i do to help my friend',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 15,
#     'text': 'i feel like im alone and have nothing positive in',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 16,
#     'text': 'im fked',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 17,
#     'text': 'got warned for telling the password to an area in',
#     'image_path': '2024-08-10_ROBLOXBans_1ep9egf_got_warned_for_telling_the_password_to_an_area_in.jpg',
#     'image_description': 'None'},
#    {'id': 18,
#     'text': 'got warned for telling the password to an area in',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 19,
#     'text': 'is it okay to have a friend do homework with you',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 20,
#     'text': 'i wish to stop existing',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'IVIRolodan',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'tired only tired',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'JackieBOYohBOY',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'these lil dudes stole my boat',
#     'image_path': '2024-08-09_Minecraft_1eoh4py_these_lil_dudes_stole_my_boat.jpg',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'how do i pretend to be happy',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'JeffGoldblumsFly1986',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'sexy',
#     'image_path': '2023-04-24_mariasharapova_12y1xy8_sexy.jpg',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'for the foot lovers out there',
#     'image_path': '2023-05-13_HailieDeeganBody2_13gjqqq_for_the_foot_lovers_out_there.jpg',
#     'image_description': 'None'},
#    {'id': 2,
#     'text': 'buying tickets straight from the venue',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 3,
#     'text': 'contracting hiv through giving oral',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 4,
#     'text': 'mood often gets worse during exercising',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 5,
#     'text': 'just a suggestion for future swinger parties',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 6,
#     'text': 'porn star appearances',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 7,
#     'text': 'any job openings right now',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'kay0rian',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'insomnia is debilitating',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'im so lost',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'KonBobQdeLiSlivi',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'searching for an asian rap song',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'ive lost control',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'littleman1213',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'so sick of in laws',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'why o why',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 2,
#     'text': 'did i lose my mind',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 3,
#     'text': '1co8fi8 its been a hard day',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 4,
#     'text': 'i cant stand myself',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 5,
#     'text': 'im so lost',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 6,
#     'text': 'hiding behind your smile',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 7,
#     'text': 'sadness',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 8,
#     'text': 'hiding',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 9,
#     'text': 'to my deceased husband',
#     'image_path': '2024-05-30_widowers_1d45r8t_to_my_deceased_husband.jpg',
#     'image_description': 'None'},
#    {'id': 10,
#     'text': 'to my deceased husband',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 11,
#     'text': 'i need help',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 12,
#     'text': 'regret',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 13,
#     'text': 'lost',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 14,
#     'text': 'what the hell',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 15,
#     'text': 'dreams after their passing',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 16,
#     'text': '1e2gn8h dreams after their passing',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 17,
#     'text': 'mad im just mad',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 18,
#     'text': 'weight loss',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 19,
#     'text': '',
#     'image_path': 'wxpgLFdUxL1etmxqA3skzSTms15NBFnbgaAbX4o1Z0Y.jpg',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'LordAni501',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'wfl',
#     'image_path': '2023-08-22_bloxfruits_15yucrp_wfl.png',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'wfl',
#     'image_path': '2023-08-24_bloxfruits_15zvrhc_wfl.png',
#     'image_description': 'None'},
#    {'id': 2,
#     'text': 'i just cant understand',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'LordLevi56',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'just a cat',
#     'image_path': '2022-07-15_rand0mph0tos_vzkvvj_just_a_cat.jpg',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'a warm welcome',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 2, 'text': ' ', 'image_path': 'None', 'image_description': 'None'},
#    {'id': 3,
#     'text': 'legális így pénzt keresni',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 4,
#     'text': 'should i main thea in 2024',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 5,
#     'text': 'motivationcool idea',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 6,
#     'text': 'is there a way to stop my sim calling his friends',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 7,
#     'text': 'what aboaut who didnt fell in battle',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 8,
#     'text': 'zombie shootout scene',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 9,
#     'text': 'death core effect on mental healt',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 10,
#     'text': 'i feel empty',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 11,
#     'text': 'i want to feel worse',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 12,
#     'text': 'does anyone know this place',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'lostinthematrix',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'mornings are the worst',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'everyone always leaves',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'maxmax342342',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'i finally feel awake after 23 years of hiding',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'cant start custom flight fs2020',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 2,
#     'text': 'crashing when i try to fly specific areas',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 3,
#     'text': 'ubuntu 1804 cpu heat fan speed and battery',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 4,
#     'text': 'slow perform when booting without ac adapter',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 5,
#     'text': 'can pills help hyperhidrosis risks side effects',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 6,
#     'text': 'how to setup esp32 chip with led strip',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 7,
#     'text': 'esp32 slow perforamance',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 8,
#     'text': 'hooch on top of the starter 2 days in',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 9,
#     'text': 'proportions for white flour sourdough bread based',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 10,
#     'text': 'loosing my sexual arousal after some time',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 11,
#     'text': 'sl56m6 should i end a relationship with fearfulavoidant',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 12,
#     'text': 'soh3je post breakup advice',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 13,
#     'text': 'why do i feel those feelings again',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 14,
#     'text': 'got into a plateau 24m',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 15,
#     'text': 'find the only winning move for white',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 16,
#     'text': 'social media for photography',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 17,
#     'text': 'transfer photos in a creative way explanation',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 18,
#     'text': 'sony 70200 f28 gm ii vs tamron 70180 f28 g2',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 19,
#     'text': 'shooting with sony a7iii remotely',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 20,
#     'text': 'how do i know antidepressants is my solution',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 21,
#     'text': 'go read some books',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 22,
#     'text': '',
#     'image_path': 'hqmO3g9hgUuezaKo4JTdg2646JphgC8uLK9uWgp6Dqs.jpg',
#     'image_description': 'None'},
#    {'id': 23,
#     'text': '',
#     'image_path': 'JgdcksPjF4QHghAQoNQT_4qKXo7lpw0To049J4PMnRU.jpg',
#     'image_description': 'None'},
#    {'id': 24,
#     'text': '',
#     'image_path': 'trjGzuz9BQDAtArM1S5Ss0CN1YMxL1Vkv8Xlcgdca5w.jpg',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'Money',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': '',
#     'image_path': '0yqwpjjOjGscDGSOXPJwv4VsasZ5KEaml7GuWxkW7sc.jpg',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'have you followed dave ramseys financial advice',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 2,
#     'text': 'cpdg3q going to college shouldnt mean a lifetime of debt',
#     'image_path': '2019-08-12_u_money_cpdg3q_going_to_college_shouldnt_mean_a_lifetime_of_debt.gif',
#     'image_description': 'None'},
#    {'id': 3,
#     'text': 'ama im the lead editor on moneys best colleges',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 4,
#     'text': '',
#     'image_path': 'abSY_prtdXDb2S2TuxEAaEcXVuSzIguSR3e5cGsXoTY.jpg',
#     'image_description': 'None'},
#    {'id': 5,
#     'text': '',
#     'image_path': 'KEzbU7Y05L53nhbmpOe6BwWtsR-Thy0poN6dQ8_nCAY.jpg',
#     'image_description': 'None'},
#    {'id': 6,
#     'text': '',
#     'image_path': 'lgPn9xvMa14keD6vks0MbxphMb9XAPiFhXUj7buW0Yg.jpg',
#     'image_description': 'None'},
#    {'id': 7,
#     'text': '',
#     'image_path': 'N7EX-WsAZ7_RyAnEZvFxw2Dp8nVV4QoUe5sjijxw5NQ.jpg',
#     'image_description': 'None'},
#    {'id': 8,
#     'text': '',
#     'image_path': 'p-7rDQQh3brv33DI5QZ9EkwHWrUpP3lpAM6V7VYf5rs.jpg',
#     'image_description': 'None'},
#    {'id': 9,
#     'text': '',
#     'image_path': 'STRm0NqcVjRuqar9ZaQDlf5yH0chkxP6E7WB4mAGjlA.jpg',
#     'image_description': 'None'},
#    {'id': 10,
#     'text': '',
#     'image_path': 'sxcpBy2m-gniJXtjMr837bGjwauIk43CVcoLdNqXhOk.jpg',
#     'image_description': 'None'},
#    {'id': 11,
#     'text': '',
#     'image_path': 'tAxQeoJErW1srL8RoDKM94ZqQEyMQZ5R494yMknyPoI.jpg',
#     'image_description': 'None'},
#    {'id': 12,
#     'text': '',
#     'image_path': 'WQ024-anaeGDCfo0iWEwQRjK1gPuI-u7hUeFsTDWIQI.jpg',
#     'image_description': 'None'},
#    {'id': 13,
#     'text': '',
#     'image_path': 'Wt6KH2l8vWvCFwKmJYuVJBu5yG91qsI0J0bxcGddAPU.jpg',
#     'image_description': 'None'},
#    {'id': 14,
#     'text': '',
#     'image_path': 'xvui0rRnq5W0xkGb7SB1Fyn-Mg2scSaNoiF1m3WuyKM.jpg',
#     'image_description': 'None'},
#    {'id': 15,
#     'text': '',
#     'image_path': 'zOJFdl7YlEeQISX10y7Xhn3Td1HnVtCn7EVgWG_VWRc.jpg',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'MousseMilkCream',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'my life is perfect not an ounce of happiness',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'mrcountry88',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'really',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'piccolo enjoying the birb music her dad put on',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 2,
#     'text': 'piccolo enjoying the birb music her dad put on 001',
#     'image_path': '2024-04-24_budgies_1cc5uia_piccolo_enjoying_the_birb_music_her_dad_put_on_001.jpg',
#     'image_description': 'None'},
#    {'id': 3,
#     'text': 'piccolo enjoying the birb music her dad put on 002',
# ...
#     'text': 'villain arc part 2',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 15,
#     'text': 'villain arc 3',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 16,
#     'text': 'did basic',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 17,
#     'text': 'that didnt work',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 18,
#     'text': 'growth',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 19,
#     'text': 'aint life grand',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 20,
#     'text': 'will',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 21,
#     'text': 'sighh',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 22,
#     'text': 'lose your v card',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 23,
#     'text': 'lifes kicking my ass',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 24,
#     'text': 'naniii',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 25,
#     'text': 'random',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 26,
#     'text': 'a cup iof water',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 27,
#     'text': 'spiral',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 28,
#     'text': 'bruh',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 29,
#     'text': 'ep888',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 30,
#     'text': 'am i ugly guys 34 year old man',
#     'image_path': '2024-09-05_amiugly_1fa7kjz_am_i_ugly_guys_34_year_old_man.jpg',
#     'image_description': 'None'},
#    {'id': 31,
#     'text': '34m',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'Uselessviewer8264',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'read description for questions',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'read description for questions 00001',
#     'image_path': '2024-06-26_coins_1dpe6aw_read_description_for_questions_00001.jpg',
#     'image_description': 'None'},
#    {'id': 2,
#     'text': 'read description for questions 00002',
#     'image_path': '2024-06-26_coins_1dpe6aw_read_description_for_questions_00002.jpg',
#     'image_description': 'None'},
#    {'id': 3,
#     'text': 'read description for questions 00003',
#     'image_path': '2024-06-26_coins_1dpe6aw_read_description_for_questions_00003.jpg',
#     'image_description': 'None'},
#    {'id': 4,
#     'text': 'read description for questions 00004',
#     'image_path': '2024-06-26_coins_1dpe6aw_read_description_for_questions_00004.jpg',
#     'image_description': 'None'},
#    {'id': 5,
#     'text': 'read description for questions 00005',
#     'image_path': '2024-06-26_coins_1dpe6aw_read_description_for_questions_00005.jpg',
#     'image_description': 'None'},
#    {'id': 6,
#     'text': 'what is this it was poking out of a bank at the 0001',
#     'image_path': '2024-06-27_Archeology_1dq3cle_what_is_this_it_was_poking_out_of_a_bank_at_the_0001.jpg',
#     'image_description': 'None'},
#    {'id': 7,
#     'text': 'what is this it was poking out of a bank at the 0002',
#     'image_path': '2024-06-27_Archeology_1dq3cle_what_is_this_it_was_poking_out_of_a_bank_at_the_0002.jpg',
#     'image_description': 'None'},
#    {'id': 8,
#     'text': 'what is this it was poking out of a bank at the 0004',
#     'image_path': '2024-06-27_Archeology_1dq3cle_what_is_this_it_was_poking_out_of_a_bank_at_the_0004.jpg',
#     'image_description': 'None'},
#    {'id': 9,
#     'text': 'how old could this be it looks pretty old to me 01',
#     'image_path': '2024-06-27_beachcombing_1dq4qp3_how_old_could_this_be_it_looks_pretty_old_to_me_01.jpg',
#     'image_description': 'None'},
#    {'id': 10,
#     'text': 'how old could this be it looks pretty old to me 02',
#     'image_path': '2024-06-27_beachcombing_1dq4qp3_how_old_could_this_be_it_looks_pretty_old_to_me_02.jpg',
#     'image_description': 'None'},
#    {'id': 11,
#     'text': 'what is it i lts really pretty and i wish i had a 001',
#     'image_path': '2024-06-27_whatsthisrock_1dq7q86_what_is_it_i_lts_really_pretty_and_i_wish_i_had_a_001.jpg',
#     'image_description': 'None'},
#    {'id': 12,
#     'text': 'what is it i lts really pretty and i wish i had a 002',
#     'image_path': '2024-06-27_whatsthisrock_1dq7q86_what_is_it_i_lts_really_pretty_and_i_wish_i_had_a_002.jpg',
#     'image_description': 'None'},
#    {'id': 13,
#     'text': 'what is it i lts really pretty and i wish i had a 003',
#     'image_path': '2024-06-27_whatsthisrock_1dq7q86_what_is_it_i_lts_really_pretty_and_i_wish_i_had_a_003.jpg',
#     'image_description': 'None'},
#    {'id': 14,
#     'text': 'heres a cleaner photo of that thing i posted 001',
#     'image_path': '2024-06-28_Archeology_1dqmj02_heres_a_cleaner_photo_of_that_thing_i_posted_001.jpg',
#     'image_description': 'None'},
#    {'id': 15,
#     'text': 'heres a cleaner photo of that thing i posted 003',
#     'image_path': '2024-06-28_Archeology_1dqmj02_heres_a_cleaner_photo_of_that_thing_i_posted_003.jpg',
#     'image_description': 'None'},
#    {'id': 16,
#     'text': '31 year old film that was with a minolta x370 my',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 17,
#     'text': '31 year old film that was with a minolta x370 my 001',
#     'image_path': '2024-07-01_filmphotography_1dt33h5_31_year_old_film_that_was_with_a_minolta_x370_my_001.jpg',
#     'image_description': 'None'},
#    {'id': 18,
#     'text': '31 year old film that was with a minolta x370 my 002',
#     'image_path': '2024-07-01_filmphotography_1dt33h5_31_year_old_film_that_was_with_a_minolta_x370_my_002.jpg',
#     'image_description': 'None'},
#    {'id': 19,
#     'text': '31 year old film that was with a minolta x370 my 003',
#     'image_path': '2024-07-01_filmphotography_1dt33h5_31_year_old_film_that_was_with_a_minolta_x370_my_003.jpg',
#     'image_description': 'None'},
#    {'id': 20,
#     'text': 'this beautiful travel alarm clock my grandmother',
#     'image_path': '2024-07-02_clocks_1du24ys_this_beautiful_travel_alarm_clock_my_grandmother.jpg',
#     'image_description': 'None'},
#    {'id': 21,
#     'text': 'should i be worried i cut myself cleaning this',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 22,
#     'text': 'should i be worried i cut myself cleaning this 02',
#     'image_path': '2024-07-11_uraniumglass_1e142s4_should_i_be_worried_i_cut_myself_cleaning_this_02.jpg',
#     'image_description': 'None'},
#    {'id': 23,
#     'text': 'a delicious rasberry turnover my mom made from',
#     'image_path': '2024-07-19_Berries_1e7fuh9_a_delicious_rasberry_turnover_my_mom_made_from.jpg',
#     'image_description': 'None'},
#    {'id': 24,
#     'text': 'alright so this is very different from whats',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 25,
#     'text': 'everyone loves brother seltzer but has anyone',
#     'image_path': '2024-08-01_BottleDigging_1ehwt06_everyone_loves_brother_seltzer_but_has_anyone.jpg',
#     'image_description': 'None'},
#    {'id': 26,
#     'text': 'just to be positive this is perennial sow thistle',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 27,
#     'text': 'just to be positive this is perennial sow thistle 001',
#     'image_path': '2024-08-20_foraging_1exako9_just_to_be_positive_this_is_perennial_sow_thistle_001.jpg',
#     'image_description': 'None'},
#    {'id': 28,
#     'text': 'just to be positive this is perennial sow thistle 002',
#     'image_path': '2024-08-20_foraging_1exako9_just_to_be_positive_this_is_perennial_sow_thistle_002.jpg',
#     'image_description': 'None'},
#    {'id': 29,
#     'text': 'just to be positive this is perennial sow thistle 003',
#     'image_path': '2024-08-20_foraging_1exako9_just_to_be_positive_this_is_perennial_sow_thistle_003.jpg',
#     'image_description': 'None'},
#    {'id': 30,
#     'text': 'what species of fern is this found in eastern',
#     'image_path': '2024-09-10_PlantIdentification_1fdykon_what_species_of_fern_is_this_found_in_eastern.jpg',
#     'image_description': 'None'},
#    {'id': 31,
#     'text': 'what is this it was poking out of a bank at the 0003',
#     'image_path': '2024-06-27_Archeology_1dq3cle_what_is_this_it_was_poking_out_of_a_bank_at_the_0003.jpg',
#     'image_description': 'None'},
#    {'id': 32,
#     'text': 'heres a cleaner photo of that thing i posted 002',
#     'image_path': '2024-06-28_Archeology_1dqmj02_heres_a_cleaner_photo_of_that_thing_i_posted_002.jpg',
#     'image_description': 'None'},
#    {'id': 33,
#     'text': 'should i be worried i cut myself cleaning this 01',
#     'image_path': '2024-07-11_uraniumglass_1e142s4_should_i_be_worried_i_cut_myself_cleaning_this_01.jpg',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'Wemeeja',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'how do i cope with hearing voices',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'i need some critique what could i improve on this',
#     'image_path': '2024-03-31_FurryArtSchool_1bs7zou_i_need_some_critique_what_could_i_improve_on_this.jpg',
#     'image_description': 'None'},
#    {'id': 2,
#     'text': 'i need some critique what could i improve on this',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 3,
#     'text': 'im thinking about submitting myself to a hospital',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 4,
#     'text': 'im goung to submit myself to a hospital or end my',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 5,
#     'text': 'i skipped school because i planned on ending my',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 6,
#     'text': 'any good scp role playing bots where you play as',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 7,
#     'text': 'my family doesnt care that i have deppressions',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 8,
#     'text': 'my family doesnt care that i have deppresoin and',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 9,
#     'text': 'what is your opinion on the furry fandom',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 10,
#     'text': 'i cant look at myself anymore',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 11,
#     'text': 'what materials should i use to make a mantis head',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 12,
#     'text': 'why does selfharm feel so good',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 13,
#     'text': 'why does selfharm feel so good',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 14,
#     'text': 'any avali comics on webtoon',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 15,
#     'text': 'i just want my father to be proud of me there are',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 16,
#     'text': 'i just want my father to be proud of me there are',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 17,
#     'text': 'your weapon of choice to take down a phantom in a',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 18,
#     'text': 'can someone explain to me why i dont have real',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 19,
#     'text': 'i think that i wont be a good femboy',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 20,
#     'text': 'why is my head telling me to stop and that im',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 21,
#     'text': 'hey fellow furries does someone know what specues',
#     'image_path': '2024-09-04_furry_1f8va99_hey_fellow_furries_does_someone_know_what_specues.jpg',
#     'image_description': 'None'},
#    {'id': 22,
#     'text': 'does anyone know how these clothes are called',
#     'image_path': '2024-09-10_GTA5Online_1fdqkwq_does_anyone_know_how_these_clothes_are_called.jpg',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'whyicantgo',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'why doesnt anyone have my back ever',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'i think i have nothing left to give to anyone',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 2,
#     'text': 'today i dont want to be alive',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 3,
#     'text': 'i am an',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'},
#  {'username': 'Wonderful-Gas-4406',
#   'depressed': -1,
#   'response': '',
#   'posts': [{'id': 0,
#     'text': 'najbolji fizijatar u srbiji',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 1,
#     'text': 'what to do when you cannot do tos surgery',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 2,
#     'text': 'severe pain when looking down during a chin tuck',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 3,
#     'text': 'no relief for 6 months of tos',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 4,
#     'text': 'preporuka ljekara za lijecenje thoracic outlet',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 5,
#     'text': 'hitno iskustva sa thoracic outlet syndrome',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 6,
#     'text': 'recovery without surgery',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 7,
#     'text': 'list of trusted tos surgeons',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 8,
#     'text': 'fizijatri u hrvatskoj i tos',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 9,
#     'text': 'najbolji fizijatar u srbiji',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 10,
#     'text': 'tos pt protocol',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 11,
#     'text': 'dva posla i doprinosi',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 12,
#     'text': 'programer u njemackoj',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 13,
#     'text': 'remote posao i porezdoprinosi',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 14,
#     'text': 'remote posao i porezidoprinosi',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 15,
#     'text': 'remote posao i porezdoprinosi',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 16,
#     'text': 'how hard is it to find a remote german customer',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 17,
#     'text': 'dva posla u bih pravni savjet za plate i doprinose',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 18,
#     'text': 'dva full time remote posla savjet oko plata i',
#     'image_path': 'None',
#     'image_description': 'None'},
#    {'id': 19,
#     'text': 'plate juniora nejasnoce',
#     'image_path': 'None',
#     'image_description': 'None'}],
#   'prompt': 'Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no'}]

# %%
users_path = "UnlabeledImages"

#reddit_data = process_reddit_data()
mentalrisk_users = process_mentalrisk_data()
fulldata = reddit_data+mentalrisk_users

for i in range(len(fulldata)):
    with open(os.path.join(users_path,f"user_{i}.json"),"w",encoding="utf8") as f:
        content=json.dumps(fulldata[i],ensure_ascii=False)
        f.write(content)

# %%
import os
import json

source_dir = "LabeledImages"
destdir = "PostPrompts"

for i,file in enumerate(os.listdir(source_dir)):
    with open(os.path.join(source_dir,file),"r") as user_data:

        userobj = json.loads(user_data.read())
        userprompt = userobj["prompt"] + "\n\n"
        postxt ="\n"

        for post in userobj["posts"]:
            postxt+=post["text"]+"\nimage content : "+post["image_description"]+"\n"

        userprompt+=postxt
        print(userprompt)

        with open(os.path.join(destdir,f"{file}.txt"),"w") as prompt:
            prompt.write(userprompt)
# Out:
# Teniendo en cuenta que el usuario está deprimido, justifica los motivos de esto con base en sus publicaciones
#
#
# Constatar lo que siento con otras personas que me confirman que sienten lo mismo me ayudará inmensanente
# image content : None
# Y no me hará sentir sola en esto
# image content : None
# Es más si vivos lo mismo ya osea quiero cara sonriendo con corazones
# image content : None
# Sentís desrrealizacion ? Vivir en una realidad paralela ?
# image content : None
# Sentís que todos los días es como el último ?
# image content : None
# A ver di me he equivocado . Es un grupo de depresión clínica o solo un sentimiento ?
# image content : None
# Víctor desde hace 15 años cariño
# image content : None
# Hola veo que alguien comentó sobre TDA
# image content : None
# Si sabe de un grupo en telegram que me diga , gracias
# image content : None
# Te mando un abrazo foryisimo
# image content : None
# Te entiendo a la perfección con lo de la fecha
# image content : None
# Y necesitar un abrazo , algo ...
# image content : None
# De verdad , te abrazo
# image content : None
# Os quiero un montón y os entiendo , corazón roto es para celebrar encontrar este tipo de detalles en tu vida , y que otros están como tu y te apoyan
# image content : None
# Si la ansiedad es muy Crónica , se tienen que sanar el dolor de tu vida o Infancia
# image content : None
# No hay pastillas , ni terapias
# image content : None
# Y eso se hace mirando de cara y sintiendo completamente tu dolor
# image content : None
# Porque tenemos mecanismos de evitación que lo empeoran y nos estancan en la vida
# image content : None
# Y do no lo afrontamos morimos , leerlos este libro " Sal de ti mente entra en tu vida " De Hayes
# image content : None
# En mi caso no fue suficiente , algo más pasó
# image content : None
# Y aún estoy en ello
# image content : None
# Psicodelia corazón roto
# image content : None
# Antes de dormir siempre igual
# image content : None
# Pero un beso y gracias
# image content : None
# Muy bien desde que me rodeo de lo que busco , tener gente como yo me hace bien
# image content : None
# Saludos cara lanzando un beso
# image content : None
# De donde eres , y que edad tienes
# image content : None
# Eres muy joven todos esas cosas que dices son debidas a tu inexperiencia
# image content : None
# No te digas tonterias , con tu fortaleza y belleza pasará
# image content : None
# En caso de que tengas algo psíquico o un handicap podrás aprender a vivir con ello
# image content : None
# Todos esos achaques son por tus heridas de desamor por lo que tu psique reacciona así pero veras que nada de eso és verdad ,
# image content : None
# En unos años te reiras de tus comentarios
# image content : None
# Pienso igual , tienen que tener pacienciq
# image content : None
# O más bien nosotros
# image content : None
# Yo tengo 28 que piensas al respecto con esa edad ?
# image content : None
# Ver la película " la cabaña " ...
# image content : None
# Ya estoy en otro grupo sobre esto
# image content : None
# Así que me despido
# image content : None
#
# Teniendo en cuenta que el usuario no está deprimido, justifica los motivos de esto con base en sus publicaciones
#
#
# Quiero matar al bebe que hago ?
# image content : None
# Tengo ganas de rajarlo por la barriga
# image content : None
# Lo mato como siga llorando
# image content : None
# Eso significa que lo mate no ?
# image content : None
# Si mi marido muerto
# image content : None
# Lo tiro por la ventana antes
# image content : None
# Me pasas un porrillo ?
# image content : None
# Porque ? Si no lo quiero
# image content : None
# Siiii ! ! ! Hay que follar como locos
# image content : None
# Yo se los quito dandolenlo suyo
# image content : None
# Yo no me drogo
# image content : None
# Para matar al bebe
# image content : None
# Yo solo no puedo
# image content : None
# Yo te quito las penas nena cara sonriendo con superioridad
# image content : None
# Tambien te las quito cara sonriendo con superioridad
# image content : None
#
# Teniendo en cuenta que el usuario está deprimido, justifica los motivos de esto con base en sus publicaciones
#
#
# Hola , yo también estoy así
# image content : None
# Estoy en un punto en el cual me molesta todo algo raro en mi , estoy qué les pego a todo los de mi familia cuando los veo , no disfruto cuando salgo con ellos
# image content : None
# Pensas que a consta de la depresión me dan ataques de rabia y dejé a mi hermana hospitalizada , estuve la semana pasada en el hospital por sobredosis , coma de tres días o sea no me duele estar así me duele sentirme así
# image content : None
# Y saben que es lo mejor para mí cuando veía borroso para desmayarme y sentí una paz que no se describe con nada
# image content : None
# La golpee muy fuerte hasta que la deje inconsciente
# image content : None
# Nada solo fui y la deje asi
# image content : None
# Yo siempre he Sido la que la caga cada año de formas diferentes pero horribles y incluso siempre pienso que por más que mis papá digan que les importo y que soy suficiente para ellos no lo creo , y si debe de sonar muy estúpido pero para mí la aprobación de mis papás es lo que nesecito , por eso tengo depresión
# image content : None
# Si lo sé , pero quiero luchar yo contra eso sin medicamentos
# image content : None
# Por eso es mejor no existir
# image content : None
# Si , siempre pero no quiero seguir cagándola es algo tan inevitable
# image content : None
# Ya lo hecho pero es hortible
# image content : None
# Si no existo no hago daño a los demás ni a mí misma
# image content : None
# Y ustedes cómo están ?
# image content : None
# Lo único que me da paz es hablar con la persona que me gusta , aquella me apoya mucho y me calma muy fácil , aquella tiene mi control
# image content : None
# Por aquella sigo viva
# image content : None
# Al menos yo sé que es bueno y malo , no le haría daño a nadie mas ,
# image content : None
# Muy bien , me apoya mucho con lo que tengo , ya está aprendiendo a calmarme y ya no me muestra miedo
# image content : None
# Una cosa es estar conciente de que agredes y otra es ver cómo tú cuerpo agrede solo
# image content : None
# Y sin tener el control tu mismo
# image content : None
# Bueno en fin todo algún día pasara
# image content : None
# Hay ya , no , yo la quiero mucho para hacerle eso conciente
# image content : None
# Me acabo de dar cuenta
# image content : None
# Si yo se pero todo bien
# image content : None
# Si , acabo de llegar de terapia
# image content : None
# Me fue super , si está funcionando , ya estoy mucho mejor en el sentido de el humor
# image content : None
# Ufff que si que
# image content : None
#
# Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no
#
#
# 1csjj9k would love some of that karma people keep talking
# image content : None
# 32 m4f west virginia looking for more than
# image content : None
#
# Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no
#
#
# how do i tell someone that i politely dont want
# image content : None
# ill never be normal
# image content : None
# spqlnv should i be as upset as i am my fiance lied about
# image content : None
# so i relapsed
# image content : None
# i left my fiance and ive almost entirely stopped
# image content : None
# i thought it would be okay
# image content : None
# im tired
# image content : None
# im tired
# image content : None
# what is your best i just noticed that moment
# image content : None
# dani is not actually blond
# image content : None
# anyone else think they were a bit over the top
# image content : None
# i dont know if i should just go back to drinking
# image content : None
# that moment you realize you could go missing and
# image content : None
# do i have depression or am i actually just lazy
# image content : None
# so there is hope
# image content : None
# do you see the potential too
# image content : a photo of a vintage trailer on facebook
# do you see the potential too
# image content : None
#
# Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no
#
#
# this point
# image content : None
# levels to it
# image content : None
# is it just me
# image content : None
# pressssssssed
# image content : None
# 32m4f
# image content : None
# tf
# image content : None
# faith
# image content : None
#
# image content : None
# what do you do
# image content : None
# venting
# image content : None
# man im dead
# image content : None
# big sighhh
# image content : None
# for the little guys
# image content : None
# okaaay
# image content : None
# villain arc part 2
# image content : None
# villain arc 3
# image content : None
# did basic
# image content : None
# that didnt work
# image content : None
# growth
# image content : None
# aint life grand
# image content : None
# will
# image content : None
# sighh
# image content : None
# lose your v card
# image content : None
# lifes kicking my ass
# image content : None
# naniii
# image content : None
# random
# image content : None
# a cup iof water
# image content : None
# spiral
# image content : None
# bruh
# image content : None
# ep888
# image content : None
# am i ugly guys 34 year old man
# image content : a man in a car wearing a hat and jacket
# 34m
# image content : None
#
# Teniendo en cuenta que el usuario está deprimido, justifica los motivos de esto con base en sus publicaciones
#
#
# Hola . Esto es un grupo de perder el tiempo hablando de cosas sin interés o de gente que realmente quiere sanar su depresión y tristeza ?
# image content : None
# Insistir en algo que no funciona es como ponerte un zapato que no te sirve , te queda pequeño , aprieta , duele , causa ampollas , y a veces hasta sangra . Por eso dicen que , muchas veces en la vida , tienes que olvidar lo que quieres , para empezar a recordar lo que te mereces ...
# image content : None
# Por lo que he leído por encima
# image content : None
# Hay que ponerse las pilas y vivir la vida que son dos días gente ! ! !
# image content : None
# Hace 1 semana empecé a tomar un producto nuevo anxibye . He estado investigando y tiene buena crítica . Quería saber si alguien más lo esta tomando ? Y como le ha ido ? Cuando da resultados ? Gracias
# image content : None
# Porque ? Lo has probado ?
# image content : None
# No entiendo entonces en que te basas para decir eso
# image content : None
# Veo que no tienes un vocabulario muy variado
# image content : None
# Gracias de todas formas
# image content : None
# Pq quiero saber si alguien lo ha tomado y saber cuanto tarda en hacer efecto
# image content : None
# Tengo mucha ansiedad y no duerme bien
# image content : None
# Muchas gracias gracias por responder cara sonriendo
# image content : None
#
# Teniendo en cuenta que el usuario está deprimido, justifica los motivos de esto con base en sus publicaciones
#
#
# En este momento yo tengo esas ideas
# image content : None
# Soy nuevo aquí , no sé solo escribi la palabra depresión y me salió este grupo no se cm llevan el grupo no de lo que hablan ... No sé si quisas aquí me.pueds desahogar la verdad no sé mucho de como llevar está situación solo pienso en jalar el gatillo de mi arma ( soy escolta ) así que bueno trato de no beber pero no logro reprimir esos recuerdos , no tengo amigos mi familia esta lejos mis compañeros de trabajo solo son conocidos no confío en nadie que porte un arma y menos confío en mi trabajo salgo por las mañana deseando no volver y vuelvo amo tanto la vida q empiezo a apreciar la muerte desde luego estar solo para mí es una tortura estoy cansado de llorar estoy cansado de solo sonreír sin querer hacerlo me siento mal necesito ayuda y no se como buscarla
# image content : None
# Solo me basta 2 kilos de presión sobre el gatillo y estar ahogado en alcohol otra vez lo perdí todo y no puedo recuperarlo
# image content : None
# Mi prometida mi hija recién nacida mi hogar lo q más valoro en mi patética vida
# image content : None
# Mi hija murió hace 6 meces hace 2 días encontré a mi prometida con un compañero de su trabajo
# image content : None
# Yo dejé de lado mi carrera militar para q ella tuviese todo
# image content : None
# Le pague la universidad
# image content : None
# Le di un hogar
# image content : None
# Todo era de ella
# image content : None
# Solo q me matan 10 años de recuerdos más los 2 años q tuve a mi niña en mis brazos
# image content : None
# Mi jefe me ofreció una vacante cm un amigo de el en la embajada americana cm analista o algo así era no se muy bien el día que el hablo conmigo la verdad estaba más ebrio q sobrio solo recuerdo q me quitaron el arma y me esposaron a la camioneta
# image content : None
#
# Teniendo en cuenta que el usuario está deprimido, justifica los motivos de esto con base en sus publicaciones
#
#
# Mal pues me siento como una bestia horripilante pero bueno , porque estas asi ?
# image content : None
# Un tipico dia gris en alguien con TLP y tu ?
# image content : None
# Trastorno limite de la personalidad o borderline
# image content : None
# Basicamente la depresion forma base del tlp asi que si entiendo que es eso
# image content : None
# Hace cuanto ? disculpa si quieres no respondas
# image content : None
# Hace cuanto te diagnosticaron ?
# image content : None
# Que mal lo siento enserio
# image content : None
# Pero debes seguir aguantando
# image content : None
# Que mal y enserio lo lamento
# image content : None
# Vivir el simple hecho de vivir ya es una razon logica
# image content : None
# Yo igual me e intentado suicidar y me quiero morir pero aqui estamos
# image content : None
# Y debemos seguir estandolo
# image content : None
# Lo mismo digo asi me han dicho y aun me dicen
# image content : None
# Igual hace unos 4 dias intente suicidarme pues perdi completamente el control de mi
# image content : None
# Forma parte de vivir todos o bueno almenos una parte desea morirse en la vida nosotros la vivimos mas dura pero es una razon por la cual seguir fuerte cada dia
# image content : None
# Porque asi demuestras lo fuerte que eres viviendo algo que piensas imposible
# image content : None
# No soy psicologo e estado casi toda mi vida con psicologo y psiquiatras y almenos e aprendido algo pues estoy avanzando como puedo
# image content : None
# Si , familia , hijos , esposo
# image content : None
# En tu caso algun dia encontraras al hombre perfecto
# image content : None
# Porque perderse esa increible experiencia ?
# image content : None
# Pues eso dices porque en estos momentos tu mente te hace creerlo
# image content : None
# Pero dia tras dia mientras intentas salir de ese hueco
# image content : None
# Veras lo lindo de la vida
# image content : None
# Alguien que no ama esas cosas porque en realidad nadie deberia de enamorarse por esas cosas el corazon se enamora de la belleza de lo buena persona que es de todo su ser
# image content : None
# Y si tiene defectos pues juntos lo arreglaran
# image content : None
# De eso se trata el amor no ?
# image content : None
# La vida es solo una y si te la pierdes no la podras tener mas debes seguir luchando para que experimentes lo hermoso del respirar
# image content : None
# Puede ser o tal vez nadie lo sabe reina
# image content : None
# Exacto reina date cuenta yo soy de venezuela tambien y esta ruda la situacion pero debemos ser fuertes ¿ no ? , si lo debemos ser
# image content : None
# Pues seamoslo aun yo igual me harte bueno hoy no pues estoy rebosando de felicidad
# image content : None
# Pero igual reina sigue adelante
# image content : None
# No tengo telefono de hecho estoy en pc
# image content : None
# Si pues seguro se termina en minutos
# image content : None
# Te entiendo a la perfeccion
# image content : None
# Mala suerte de un dia otro dia sera mejor
# image content : None
# Bien eso creo y tu ?
# image content : None
# La vida es y siempre sera una gran mierda
# image content : None
# * La vida es una mierda y siempre sera ninguna explicacion acerca de eso la aceptare porque son estupideces
# image content : None
# Existe alguna medicina o farmaco para no sentir este gran vacio ?
# image content : None
# El amor no me llena
# image content : None
# por tiempo estuve intentando llenar mi vacio con personas con drogas con alchool y solo me arruine mi vida
# image content : None
# Tuve segun 2 amores perfectos en mi vida y todo en realidad se formo un puto caos
# image content : None
# Tengo ganas de llamar a mi psicologo ¿ sera que lo hago ? hablo con alguien ?
# image content : None
# Bah que aburrido suenas igual que todos los psicologos con los que estuve
# image content : None
# Porque ver el problema desde afuera de el no es tan sencillo como vivirlo a diario
# image content : None
# ¿ Que te diagnosticaron ?
# image content : None
# Por una semana me diagnosticaron eso y luego me diagnosticaron con trastorno limite de la personalidad y aparentemente es
# image content : None
# Yo estoy ahora con terapia y medicamentos
# image content : None
# Como ser positivo con una vida de mierda
# image content : None
# Mierda es un no profundo
# image content : None
# Es mejor no serlo
# image content : None
# Deja de decir pendejadas por favor
# image content : None
# Te encanta ? es un chiste ?
# image content : None
# Ahora comprendo porque cada psicologo deja de ayudarme
# image content : None
# Bien todo tiene sentido soy una mierda entera
# image content : None
# Mas a mi favor no me conoces no sabes lo basura y porqueria que soy
# image content : None
# Pues era un estupido por dar y decir cosas que no son realidad
# image content : None
# de hecho espero que aun este mal esa chica
# image content : None
# Para que se de cuenta que la realidad es toda basura y nada tiene sentido
# image content : None
# El solo hecho de respirar no tiene sentido nada lo tiene
# image content : None
# Asco esas palabras me dan igual
# image content : None
# asi que me da igual
# image content : None
# Mis ojos cada parte de mi es horrible
# image content : None
# Para que mirarme si solo querre matarme aun mas ?
# image content : None
# Hablan puras estupideces enserio cara llorando de risa
# image content : None
# Viven en la no realidad
# image content : None
# Da igual yo se que no es la verdad
# image content : None
# QUE PROBLEMA EXISTE SI QUIERO HACERLO ?
# image content : None
# No sabes que es el sufrimiento real niño
# image content : None
# No entiendes porque eres el 99 % de la gente feliz
# image content : None
# No sabes como se siente sufrir cada dia
# image content : None
# QUE ERES UN IMBECIL DE MIERDA
# image content : None
# Que hay que desahogar ?
# image content : None
# Fuerte nosotros tu un imbecil de mierda
# image content : None
# Fuerte es aquel que se queja de un dolor real no de una estupides
# image content : None
# Y tu seguiras en tu estupides ?
# image content : None
# Mejor que alguien que sufre en realidad ?
# image content : None
# Y tu llorando por estupideces ?
# image content : None
# Quien es mejor que quien ?
# image content : None
# el duro que intenta solucionarse o el idiota que piensa que tiene peor que los demas
# image content : None
# Muchos mensajes lamayoria es estupides asi que no leere nada
# image content : None
# ¿ Mas o menos ? ayer me dio una crisis
# image content : None
# Diria bien pero , ¿ are no ?
# image content : None
# Electrico que sufres tu ?
# image content : None
# ¿ Todo te lo causo una mujer ?
# image content : None
# Que mal , pero sufrir tanto por una mujer no me parece cuerdo
# image content : None
# No lo se no llevo la cuenta pero a mi no me paso lo que me paso por una estupida mujer
# image content : None
# No soy tan debil
# image content : None
# Ami no me dieron por consumo de sustancias
# image content : None
# A ti te dieron por una mujer , ¿ te hace debil o imbecil ?
# image content : None
# Y que cualquiera te diria imbecil y marica por dejar que una mujer te dañe tanto
# image content : None
# No hay nada que empezar le hice reflexionar acerca de su estupides
# image content : None
# ¿ Es traumatico que una mujer te deje ?
# image content : None
# ¿ Es mas traumatico que un adulto te viole de niño ?
# image content : None
# Puedes decir lo que quieras y te respeto pero me parece estupides sufrir por una mujer
# image content : None
# Media hora escribiendo electrico y me valdra verga lo que diga sigue y sera estupido hasta que se de cuenta
# image content : None
# Te imaginas que hubiese tenido mi infancia o la de alguno de aca pffff hubiera quedado en un psiquiatrico de por vida porque se ve que es debil , nadie sufre tanto por una mujer
# image content : None
# Electrico aun sigue escribiendo no mames
# image content : None
# Solo me molesta un poco personas que se quejan o sufren tanto por algo minimo en vez de no pasarlo tanto
# image content : None
# mucho texto me da igual : 3 leelo tu solo
# image content : None
#
# Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no
#
#
# more changes
# image content : None
# thoughts on the betrayal
# image content : None
# watching the doc
# image content : None
# my ratings of s1
# image content : None
# i dont know what to do anymore
# image content : None
# season 2 renewal
# image content : None
# nonfan first thoughts
# image content : None
# lunch break as minor
# image content : None
# about stocking
# image content : None
# adhd and belts
# image content : None
# dont look at me like that
# image content : None
# haha nice
# image content : a screen shot of the balance page on the website
# i just want to live in my dreams
# image content : None
# question abt discount card
# image content : None
#
# Teniendo en cuenta que el usuario no está deprimido, justifica los motivos de esto con base en sus publicaciones
#
#
# Acá aburrido duro viendo freddy
# image content : None
# No voy a poder dormir
# image content : None
# Si si está bien puesto el nombre ... me pasan una galletita de agua así me corto las venas
# image content : None
# Y ... acá .. se escucha de fondo un cri cri
# image content : None
# Algo me dice que espere sentado
# image content : None
# Por que no vas a escribir nda
# image content : None
# Bueno creo que es el fin
# image content : None
# Me queda poco combustible
# image content : None
# Abh y por qué modo lucha ? ?
# image content : None
# Por ? Si se puede saber
# image content : None
# Ahora en este momento no ... estas aho
# image content : None
# No molesto mas por las dudas
# image content : None
# Y algo que te ponga alegre
# image content : None
# Nada que levante un poco ? ?
# image content : None
#
# Teniendo en cuenta que el usuario está deprimido, justifica los motivos de esto con base en sus publicaciones
#
#
# ¿ Cuanto tiempo duraron así ?
# image content : None
# sí , pero ya nos mandaron a la tercera edad cara con ceja alzada
# image content : None
# Lo bueno es que no hayan sido mas
# image content : None
# Yo tbn me voy a dormir xq luego no me puedo levantar
# image content : None
# Es lo ideal porque psicológicamente el ser humano necesita tener a su mamá y a su papá
# image content : None
# Y saber pedir perdón y perdonar
# image content : None
# Cansada , fue un dia de mucha actividad . Espero q tú te sientas mejor
# image content : None
# Saber llegar a acuerdos
# image content : None
# Algo pude leer . Que bueno que estás mejor
# image content : None
# Pues sí , fue productivo . Pero me estreso cuando hay muchp qué hacer y poco tiempo , jeje
# image content : None
# Siempre se va volando , especialmente cuando uno necesita que rinda mas cara llorando de risa
# image content : None
# Cumbia notas musicales nota musical a bailar en vez de dormir
# image content : None
# Me gusta exclamación de corazón
# image content : None
# Por lo wue se , la neuralgia del trigémino es un dolor insoportable
# image content : None
# Si coincide con la ansiedad podria ser una contractura muscular
# image content : None
# Sin ganas de hacer nada cara sonriendo con sudor frío
# image content : None
# Algo . He dormido poco los ultimos dos dias y simplemente solo quiero dormir
# image content : None
# Yo x las mañanas despierto cansada
# image content : None
# Una vez me recetaron un relajante muscular para una contractura del cuello que me originó mareos
# image content : None
# Quiza sea bueno q vayas al medico especificamente x lo de tu dolor
# image content : None
# Yo quiero despertar con ánimo
# image content : None
# Que los músculos se contraen fuertemente
# image content : None
# Despierto y solo de pensar en todo lo q tngo q hcr me abrumo y adios cualquier brizna de alegría cara decepcionada
# image content : None
# Doy gracias a Dios por haber despertado con vida , intento levantarme de la cama pero a veces el sueño me vence y me vuelvo a dormir , pienso en lo que tengo q hacer en el dia y me estreso x ello ...
# image content : None
# Soy acumuladora , tengo un desastre en casa . Solo el verlo me desanima . Arreglar el desorden se parece a subir una montaña empinada Y luego ir a hacer compras y mandados , desinfectar las compras , cocinar ... Se me va el dia en eso
# image content : None
# No entendi cara sonriendo con sudor frío
# image content : None
# Lo sé cara con sudor frío
# image content : None
# Tú pregunta sí la entendí y respondí . Me refería a q no entendí lo wue dijo Diego .
# image content : None
# Perdón , no había visto este msj . Me ocupo de mi casa y de mi papá , q ya está mayor
# image content : None
# qué te dice el médico ?
# image content : None
# Tirarlas es justamente la parte dificil . Pero estoy en terapia
# image content : None
# ¿ Será problema en los cartílagos , muscular o de los huesos ? En la radiografía deberia verse , creo . Te ha visto un traumatologo ?
# image content : None
# Pues entpnces ve aunq sea un rato
# image content : None
# A vcs yo tbn soy indecisa
# image content : None
# Nadar dicen q es muy bueno !
# image content : None
# Yo nunca he ido . Prefiero salir a caminar en la naturaleza
# image content : None
# Parque con arboles , ja
# image content : None
# Ese es un típico pensamiento producido por la depresión , por lo cual es falso y no hay que hacerle caso
# image content : None
# Ella no sabe como reaccionar
# image content : None
# Sigue viviendo . Si te matas ya no habrá soluciones
# image content : None
# Yo agradezco no haberme matado
# image content : None
# Te entendemos . Tambien nos hemos sentido asi
# image content : None
# ¿ Dejar de sufrir , mas bien , no ?
# image content : None
# Morir no te soluciona eso .
# image content : None
# Te abrazo en la distancia
# image content : None
# Eres un ser humano valioso , mereces estar bien , no mereces morir
# image content : None
# Desahógate aquí , te sentirás mejor . No hagas nada de lo que puedas arrepentirte después . Y recuerda que cuentas con nuestros ojos psra leerte , nurstros hombros p q llores y nuestro corazon pars quererte corazón azul
# image content : None
# Aquí , acompañandp a mi papá a su cita medica mensual
# image content : None
# Muy bien cara sonriendo ligeramente
# image content : None
# Sí , + de 4000 msjs cara gritando de miedo
# image content : None
# Ninguna mono con los ojos tapados
# image content : None
# Hay aplicaciones p aprender idiomas . No he usado ninguns pero dice que duolingo es buena
# image content : None
# Yes cara radiante con ojos sonrientes best wishes ( mis mejores deseos )
# image content : None
# Q bno q te sientes bien .
# image content : None
# Mejor que en la mañana . Todo el dia estuve sin ganas de hcr nada , toda ls semana estuve así , pero después de una sesion de jardinería me senti mejor cara feliz con ojos sonrientes
# image content : None
# Sí , gracias por alegrarte
# image content : None
# Hola , hay tests para orientarse si uno es PAS .
# image content : None
# ¿ Y qué emoción te genera pensar eso ? ¿ Te agrada o te angustia ?
# image content : None
# Oh ... cara desanimada Sigue el consejo de Nelson y tbn trata de ir con un psicólogo
# image content : None
# Hola . Solo paso a saludar antes de irme a dormir .
# image content : None
# Yo tbn me he sentido excluida , ignorada , invisible . No tanto en mi familia , pero sí en otros ambientes
# image content : None
# No es el único , pero sí uno muy bueno cara feliz con ojos sonrientes
# image content : None
# Perdida entre tantos mensajes cara llorando de risa cara llorando de risa cara llorando de risa
# image content : None
# No sé como explicarlo . Estar con gente que te importa o que hace mucho tmpo no ves y que no te hagan caso , se siente decepcionante . Duele . Pero me di cuenta de que a veces no es que me ignoren a proposito , sino que YO me siento ignorada por ellos . El problema es mío
# image content : None
# Estaban preguntando cuantos mexicanos estamos
# image content : None
# Gracias . Lo voy superando cara feliz con ojos sonrientes
# image content : None
# Solía sentirme así , hasta que me di cuents de q soy yo la q lo interpreta de esa manera
# image content : None
# No cara sonriente
# image content : None
# Yo tbn me voy a dormir . Ojalá todos puedan descansar esta noche
# image content : None
# La desesperanza y sentirse inútil son síntomas de depresión . Ademas , cuando uno está deprimido cuesta más trabajo estudiar . Es importante buscar ayuda profesional .
# image content : None
# Hola , ¿ cómo sigues de tu corazón ?
# image content : None
# Qué bien cara feliz con ojos sonrientes . Yo tbn bien , gracias . Luchando con mi desorden mono con los ojos tapados cara sonriendo con sudor frío
# image content : None
# Los sueños suelen tratar de las vivencias del día , lo q deseamos o lo que tememos 🤷‍♀
# image content : None
# Hola todos Solo paso a saludar y a quejarme , jeje . Quejarme de todo el trabajo que hay que hacer en casa y que no tengo ganas de hacerlo , pero no me queda de otra xq nadie más lo puede hacer cara de frustración Yo lo que quiero es acostarme a dormir o salirme a ver a dónde o ... No sé .
# image content : None
# Acá en México le decimos chochos a las esferitas de azúcar con medicamento que dan los homeópatas .
# image content : None
# O cuando alguien esta muy viejito dicen que " chochea " . No se si signifiq algo mas
# image content : None
# Estoy cansada de mi desorden , pero al momento de abordarlo parece una montaña enorme , imposible lidiar con él
# image content : None
# Pareciera q nunca terminaré . Este problema de acumulación no es severo , incluso dice mi psicóloga q no llega a ser un trastorno , pero es lo suficientemente complicado para hacerme sentir paralizada y con los nervios de punta
# image content : None
# Pero sí , me sentiré mjor , gracias
# image content : None
# Hola . Sí , aunque sea de a poquito , gracias cara sonriendo ligeramente
# image content : None
# Hola todos , cómo están ?
# image content : None
# Más de 4000 mensajes desde la última vez
# image content : None
# Yo ahorita no me siento muy bien , siento que no puedo avanzar , que no hago nada productivo con mi vida , que soy un desastre . Me siento muy insegura de mí misma
# image content : None
# Faltaría que ellos quisieran
# image content : None
# Puedes hacer el intento cara sonriendo ligeramente
# image content : None
# Lamento que te sientas solo . Yo tbn necesito un impulso
# image content : None
# Bien , gracias . Y tú ?
# image content : None
# Sentir que no vales la pena es propio de la depresión . Es un síntoma más pero no es la realidad . La depresion nos hace creer y sentir eso .
# image content : None
# ¿ Desde hace cuanto tiempo estás con medicamento y terapia ?
# image content : None
# Hola , sí , entro de cuando en cuando
# image content : None
# ¿ Qué tiene que ver la edad ? El amor puede llegar a cualwuier edad . Valórate , cuídate , quiérete primero tú misma y lo demás llegará después .
# image content : None
# Muy bien . Ahora enfócate en el presente , es este momento el q puedes aprovechar para trabajar en ti . Y si crees en Dios , acércate más a el , eres su hija amada , vívelo ! cara feliz con ojos sonrientes
# image content : None
# Hola , estan hablando de hipertensión ? Cuídense , es delicado
# image content : None
# Entonces solo te sube cuando estás ansioso ?
# image content : None
# Por favor compañero , lee con atención lo q te escribió May .
# image content : None
# Puedes golpear una almohada
# image content : None
# Necesitas ir a tratamiento para tu depresión . La terapia realmente puede ayudar
# image content : None
# Mi mamá a veces se sentía así , como un fastidio , y me daba una impotencia tremenda no poder convencerla de que sí la quería y sí me importaba cara decepcionada
# image content : None
# Falleció hace ya varios años
# image content : None
# Gracias . En sus momentos depresivos pensaba así , que no era querida por nosotros . No se sentía valorada . Quizá nosotros no supimos transmitírselo . Cometimos errores , pero sí la quisimos .
# image content : None
#
# Teniendo en cuenta que el usuario no está deprimido, justifica los motivos de esto con base en sus publicaciones
#
#
# ¿ Qué te ocurre ?
# image content : None
# ¿ Frío por desinterés o frío porque no sabe cómo expresarse y lo manifiesta así ?
# image content : None
# Y tú eres quién al final termina sufriendo de más
# image content : None
# ¿ Sigues teniendo comunicación con esa persona ?
# image content : None
# Por ahí no es .
# image content : None
# ¿ Autodestruyéndote en el camino ? Ujumm ...
# image content : None
# Das , das y das pero no recibes . En cualquier tipo de relación se da y se recibe . Si no lo hacen contigo , entonces por ahí no es . Y duele muchísimo .
# image content : None
# Estás así porque te importa y te duele la actitud que tiene contigo . ¿ Le has comentado como te sientes por sus actitudes de desinterés ? Quizá exista la posibilidad de que todo haya sido una confunsión , o quizá su desinterés es real y lo primero que quedaría por hacer es alejarse .
# image content : None
# Hablar de lo que sientes NO ES EXAGERAR . Si esa persona lo ve como una exageración , sumándole la falta de interés , entonces no tendría sentido ( por más que duela ) seguir aferrándote a alguien que no te entiende , y lo único que estás recibiendo es dolor .
# image content : None
# De nada . Solo ... no te consumas . vela
# image content : None
# No te consumas así , que otra llama no acabe contigo . Tú eres llama , a veces ardes más y otras no . Sabes que alguna vez te tendrás que consumir . Tú también eres cera , eres o tienes un soporte . Nada dura para siempre , mientras tanto solo nos queda ¿ sobrevivir ? . Arde como llama y sostente como cera . Arderás tanto que te vas a consumir . Pero que el fuego sea por ti , por tu luz . No ardas por la oscuridad de alguién más . No dejes que alguién más te consuma . No permitas que alguien más te apague . Si te vas a consumir , que sea por ti . No te consumas por la culpa de otra llama .
# image content : None
# ¿ Alguien más se comunicaba con él ?
# image content : None
# Hola . Yo soy Abby . Podemos charlar normal . Sin prejuicios . En sí , intentar ayudarnos entre nosotros .
# image content : None
# Ese y el de los michis . Fin
# image content : None
# Yo no llamaría AMOR a perderte a ti mismo por alguien más .
# image content : None
# Yo creo que eso ya queda en cada quién . Personalmente , no retendría mi felicidad o mi vida en general por los errores de otros , no me estancaría en eso .
# image content : None
#
# Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no
#
#
# how to win against weird strat created in vacuum
# image content : None
# i suck as rogue and i dont really know how to get
# image content : None
# can someone tell me whats wrong with my deck
# image content : None
# what is the most insidious cologne i can wear
# image content : None
# ive never watched a single episode of digimon and
# image content : None
# trying to make an edh deck with alrund god of the
# image content : None
# imo slaughterhouse 2 is the worst song on you
# image content : None
# relaxing music for a metal head
# image content : None
#
# image content : a painting of a green monster with big eyes
#
# Teniendo en cuenta que el usuario está deprimido, justifica los motivos de esto con base en sus publicaciones
#
#
# No tengo ganas de nada , solo quiera morirme y listo , ya no tener que convivir mas con mi mente
# image content : None
# Coincido , a mi ya NINGUN antidepresivo me hace efecto
# image content : None
# Tengo 22 años y desde los 15 años tomo antidepresivos ( estuve 1 año sin tomar ) . Nunca me hicieron efecto totalmente , nunca volvi a ser la que era , nunca volvi a sentirme como una persona normal , que podia hacer cosas , que socializaba un monton , que le gustaba hacer cosas . En 2014/2015 me hicieron un poco de efecto , pude hacer un poco mas llevadera mi vida , bajaron mi ansiedad , me senti un poco menos vacia , pero ahora pareciera que nada me hace efecto
# image content : None
# Lo vi ese video , y me siento igual que ella
# image content : None
# Me diagnosticaron fobia social
# image content : None
# Es horrible , no se lo deseo a nadie , fobia social con depresiom
# image content : None
# No , el antisocial creo que no teme a la mirada del otro , no le interesa agradar , simplemente siente odio hacia los demas
# image content : None
# Si , no se puede ser uno mismo nunca
# image content : None
# No se si clasificaria como antisocial
# image content : None
# Yo conozco la fobia social porq es lo que tengo
# image content : None
# Si es muy feo
# image content : None
# Es muy feo sentir que no tenes nada de que hablar
# image content : None
# O nada interesante para decir
# image content : None
# Ni yo cara desanimada
# image content : None
# Es que estamos todos por algo en comun
# image content : None
# Pero por lo general en la vida me paralizo , cuando estoy con otras personas me paralizo totalmente
# image content : None
# Y aun asi me cuesta hablar xd
# image content : None
# No obvio , es muy productivo , pero no es lo mismo si se habla en persona
# image content : None
# Yo tambien estoy triste
# image content : None
# El otro dia vino gente a casa
# image content : None
# Unos chicos y eramos 2 chicas
# image content : None
# Y los pibes ni me miraron
# image content : None
# Me siento re fea
# image content : None
# Ay corazón rojo
# image content : None
# La terapia cognitivo conductual
# image content : None
# No , los farmacos son una miersa
# image content : None
# Funcionan un tiempo nada mas
# image content : None
# Despues ya no hacen efecto
# image content : None
# Siento una profunda tristeza
# image content : None
# Mis pensamientos negativos carcomen mi cabeza , destruyen mi vida
# image content : None
# Es una terapia que se centra mucho en los pensamientos disfuncionales
# image content : None
# Que esos pensamientos son los que hacen que estes mal
# image content : None
# Y que es lo que te hace mal ?
# image content : None
#
# Teniendo en cuenta que el usuario no está deprimido, justifica los motivos de esto con base en sus publicaciones
#
#
# Tu amiga o tu novia ? ?
# image content : None
# Porque sientes eso ? ? Q actitudes tienes frente a las demás personas ? ?
# image content : None
# No te tomsn en cuenta tus amigos o todo tu entorno ? ?
# image content : None
# Te pregunto porque si som amigos talves tendrías que cambiar tus amistades y si es tu familoa talves poder conversar con ellos o acercarte un poco más
# image content : None
# Chicos porque suicidarse ? ? Que conseguir con eso ? . Cuéntanos que es lo que sientes para llegar a esa situación , talves asi te podemos ayudar
# image content : None
# No digas eso por q no sabemos lo q esta pasando
# image content : None
# Esta bien pero pero como . Nosotros lo tomamos o lo llevamos talves el . No lo lleva de esa . Manera
# image content : None
# Eso si es un buen consejo
# image content : None
# Pues ahora tienes maa de 400 amigos cara saboreando comida
# image content : None
# Seguro que lo vas hcer solo sonrie diariamente
# image content : None
# El dinero no te da felicidad
# image content : None
# Pues ya tienes cara saboreando comida
# image content : None
# Obvio pero no te da la felicidad . Puedes ser muy pobre y ser feliz
# image content : None
# Ayy Geor que materialista cara de alivio
# image content : None
# Eso mismo valorar lo que tienes
# image content : None
# Con tu mensaje parece q estarías comprando amigos .
# image content : None
# cara con ojos en blanco cara con ojos en blanco cara con ojos en blanco Que ? ? Ayy por Dios tu personalidad es lo q tr hace atractivo no el dinero
# image content : None
# cara gritando de miedo cara gritando de miedo Estas recién comenzando tu vida
# image content : None
# Pero no tienes q aferrarte a tus amigos tampoco , elloa te quieren pero no por eso tienen que estar a tu lado todo el tiempo . Yo trngp varios amigos y los veo algunoa y ottos no y sino pueden vernps pues esta bien no son parte mio
# image content : None
# No te sientas mal por eso es algo normal , por q tus amigos tienen una vida y cosas q hacer y sino te.llaman es por q talves tu errs muy aprensivo osea como hablas talves los estas asfixiando . Pero te dire q es normal q tus amigos no tr llamen o te busquen todo el tiempo
# image content : None
# Tranquilo si son realmente tus amigos los volverás a ver y sino pues hay muchas personas por conocer . Eres joven aún asi que tranquilo tienes un largo camino por recorrer y se que si todo lo ves positivo te ira bien . No mucha vanalidad ojoo pero sonrie cada dia sigue adelante y todo te ira bien .
# image content : None
# Feliz cumpleaños cañón de confeti cañón de confeti
# image content : None
# Es difícil dejar de sentirse mal en tu situación pero no imposible de salir adelante . Tú puedes .
# image content : None
#
# Teniendo en cuenta que el usuario no está deprimido, justifica los motivos de esto con base en sus publicaciones
#
#
# Nada , que empezaron mis vacaciones y me agarra un aburrimiento que roza en depresión
# image content : None
# Son todos re amables acá . Eso no se encuentra mucho en los grupos masivos
# image content : None
# Si , pero no tengo amigos amigos con los que juntarme seguido
# image content : None
# Igualmente estoy bien . Gracias por preguntar
# image content : None
# A mí me decía la página en la que lo encontré que era de Argentina
# image content : None
# Pero está lleno de distintas nacionalidades
# image content : None
# Tentativa es cuando te quedaste a medio camino ?
# image content : None
# Tipo lo intentaste pero solo te dejo cicatriz
# image content : None
# No te da cosa por tu vieja ?
# image content : None
# Yo soy de Córdoba
# image content : None
# Si te pasas por acá te espero con un fernetaso
# image content : None
# Si pasas por capital avisa . Queda re lejos Carlos Paz de dónde vivo
# image content : None
# Alguien tiene para recomendar una serie / película para el sábado ?
# image content : None
# Me tengo que poner al día con el animé . Todavía no ví la tercera de attck on Titan
# image content : None
# Las vi a las dos jajaja . Un embole que la hayan cancelado a vis a vis , no me gustó cómo cerro . Por suerte ya sale la segunda de you
# image content : None
# Ya está , me la termino antes de año nuevo
# image content : None
# Si te gustó You te puede gustar society de Netflix . La viste ?
# image content : None
# Imagínate que te vas de viaje de egresados y cuando volves no hay nadie
# image content : None
# La serie trata de como se empiezan a organizar
# image content : None
# Es como que tuviste tan por sentado que el colegio era parte de tu vida que ahora pensar en que lo vas a dejar es medio desconcertante
# image content : None
# Y no tienen orientación vocacional
# image content : None
# Me suena medio egoísta . Pero no te conozco como para decirlo sintiendolo de verdad
# image content : None
# Quizá deberías alejarte de las personas que te hacen pensar así
# image content : None
# Es egoísta querer que piensen todo el día en vos
# image content : None
# Evidentemente hay algo mal ahí
# image content : None
# La otra chica dice que se siente sola a pesar de tener amigos . No me parece que le digamos que eso está bien y que es normal , algo común de la vida
# image content : None
# Eso de guardarse las cosas no es de valiente . Y si tenés los problemas que estás describiendo deberías pedir ayuda profesional
# image content : None
# La solución es un psicólogo no un grupo de apoyo . La gente que participa acá no esta capacitada en la misma manera que un profesional y tranquilamente lo que te decímos acá puede ser desinformación
# image content : None
# El ir a psicólogo no es cuestión de ser juzgado , es cuestión de aceptar que se tiene un problema y trabajarlos con una persona que estudió para lidiar con ellos
# image content : None
# Es otro ser . Pero estudio una carrera que le exige un entendimiento de la dimensión emocional de una persona . A diferencia de nosostros
# image content : None
# El psicoanálisis ni es el único método de la psicología , y , como todo campo investigativo , cuenta con corrientes de pensamiento que tranquilamente pueden contradecirse
# image content : None
# Mi hermana se autolesionaba . Te puedo asegurar que sin un psicólogo iba a terminar mal y ella misma me cuenta que acudiendo a un profesional fue capaz de ver las cosas desde una perspectiva diferente
# image content : None
# Y cuántas personas hay que consideraron la ayuda profesional imprescindible para superar dificultades emocionales ?
# image content : None
# Si , pero si alguien me dice que se autolesiona y me dice que tiene relaciones tóxicas no le digo que es normal y que vea cómo lo resuelve . Más bien le recomiendo que asista con personas que si bien no tiene respuestas absolutas , es mínimamente capaz de aconsejarle en cuanto a su salud emocional
# image content : None
# Bueno . Pero cuan opinable es un tema cuando la salud de una persona está en juego ?
# image content : None
# Si a una mujer que le pegan vos le decís que lo resuelva como le parezca probablemente niegue que tiene un problema . Y sin insistencia probablemente ni llegué a acudir ni a la policía ni al psicólogo hasta que sea demasiado tarde
# image content : None
# Yo trato de decirte porque desacuerdo con vos
# image content : None
# No pretendo desacreditarte . Cuando vos me tiras un argumento yo te tiro el argumento por el que desacuerdo con vos . Perdón si te sentiste atacado , no era mi intención , pero siempre va a haber desidencia entre personas
# image content : None
# Eso es lo que se espera de psicologo
# image content : None
# Que te haga razonar de otra manera
# image content : None
# Si te respondiera por qué desacuerdo con vos estaría siendo redundante
# image content : None
# Pero por lo menos quedó registrado el por qué de cada uno
# image content : None
# Claro , porque me parece que cuando una persona con problemas emocionales serios decide solocionarlos por si misma puede terminar mal . Un ejemplo de aquellos son la mujeres que sufren maltrato de su pareja
# image content : None
# Claro que es todo un camino aceptar que se tiene un problema . Pero llegado el caso deberías recurrir a un profesional , porque no todos pueden dar un " bue consejo "
# image content : None
#
# Teniendo en cuenta que el usuario está deprimido, justifica los motivos de esto con base en sus publicaciones
#
#
# Alguien sabe como puedo controlar el pánico ? ... xf necesito respuestas
# image content : None
# Gracias .. gracias , muchas gracias
# image content : None
# Estoy por hacer eso ..
# image content : None
# Espero calme un poco ..
# image content : None
# Si , si .. me va calmando , muchas gracias ..
# image content : None
# Aveces me pasa esto de la nada y comienzo a llorar ... o a sentirme molesta conmigo misma .
# image content : None
# Tengo imsomnio casi todas las noches
# image content : None
# No tengo a nadie de confianza que sepa entenderme ...
# image content : None
# También me suele pasar que no me siento segura en ningún lugar más q en mi casa .. o en mi pieza
# image content : None
# Si lo pensé muchisimo ... pero no lo intente
# image content : None
# Si .. un poco quiere volver .. pero hago todo lo posible para controlarlo
# image content : None
# Em puede ser una película ?
# image content : None
# Digo , nose ... pregunto awwww .. yo y mis preguntas !
# image content : None
#
# Teniendo en cuenta que el usuario no está deprimido, justifica los motivos de esto con base en sus publicaciones
#
#
# Dicen que : perder por aprender no es perder . cara sonrojada
# image content : None
# cara babeando cara babeando cara babeando se ve rico
# image content : None
# Por ahora , relájate un poco , no pienses tanto esas cosas , vales mucho , no te dejes llevar . Calma , calma . pulgar hacia arriba
# image content : None
# Lo importante es que fisicamente estés sano , y eso te anime a seguir .
# image content : None
# Estás en forma ? Cuánto te falta para el promedio ?
# image content : None
# Pero ahora estás a tono pulgar hacia arriba
# image content : None
# Si , es el ideal .
# image content : None
# Falta muy poco . Eres perseverante
# image content : None
# Todo al tiempo es complejo .
# image content : None
# Por supuesto que sí . Pero en medio de la turbulencia , tú perseveras y logras cosas pasó a paso .
# image content : None
# Tienes la capacidad de convertir tus quejas en oportunidades , mira que escribes wow . USA's una narrativa rica .
# image content : None
#
# Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no
#
#
# damn
# image content : a screenshot of the stock market on the app
# what does the word kaeaba means
# image content : None
# i cant enjoy anything
# image content : None
# ...
# image content : None
# Ese es mi consejo
# image content : None
# Primero comeselo y q ella termine
# image content : None
# Así luego vas sin presion
# image content : None
# Al eñla estar liberada
# image content : None
# prohibido
# image content : None
# Eso va a decir ella
# image content : None
#
# Trata de inferir si el usuario, con base en la descripción textual de sus publicaciones, presenta síntomas de depresión o no
#
#
# how do i cope with hearing voices
# image content : None
# i need some critique what could i improve on this
# image content : a drawing of a dog with a head and ears
# i need some critique what could i improve on this
# image content : None
# im thinking about submitting myself to a hospital
# image content : None
# im goung to submit myself to a hospital or end my
# image content : None
# i skipped school because i planned on ending my
# image content : None
# any good scp role playing bots where you play as
# image content : None
# my family doesnt care that i have deppressions
# image content : None
# my family doesnt care that i have deppresoin and
# image content : None
# what is your opinion on the furry fandom
# image content : None
# i cant look at myself anymore
# image content : None
# what materials should i use to make a mantis head
# image content : None
# why does selfharm feel so good
# image content : None
# why does selfharm feel so good
# image content : None
# any avali comics on webtoon
# image content : None
# i just want my father to be proud of me there are
# image content : None
# i just want my father to be proud of me there are
# image content : None
# your weapon of choice to take down a phantom in a
# image content : None
# can someone explain to me why i dont have real
# image content : None
# i think that i wont be a good femboy
# image content : None
# why is my head telling me to stop and that im
# image content : None
# hey fellow furries does someone know what specues
# image content : an angel hugging a dog
# does anyone know how these clothes are called
# image content : a person sitting on a bench with a skateboard
#
# Teniendo en cuenta que el usuario está deprimido, justifica los motivos de esto con base en sus publicaciones
#
#
# Que pasó con el boludo que subiría un video como a las 8
# image content : None
# : u pense que ya me habían eliminado , la verdad no escribo porque no tengo demasiado ue escribir , les mando un saludo a todos
# image content : None
# Hay un libro que explica todo eso
# image content : None
# Como se siente cada método y la eficacia
# image content : None
# Se llama el completo manual del suicidio
# image content : None
# Debe de haber traducciones no oficiales
# image content : None
# En aokigahara se han encontrado copias de ese libro junto a cadaveres
# image content : None
# Por eso es un libro prohibido
# image content : None
# Supongo que también por eso no hsy traducciones oficiales
# image content : None
# Suicidarse es la solución permanente a problemas temporales , todo pasa y seguramente lo que estaa viviendo también pasará
# image content : None
# : u me costó 2 años de terapia meditar eso
# image content : None
# Han leído a Bertrand Russell ?
# image content : None
# El hablaba sobre el cariño y porque nos duele que no nos demuestren afecto
# image content : None
# Esperen les comparto el audio
# image content : None
# La conquista de la felicidad
# image content : None
# Quieren que les cuente por que entre en depresión o quieren ver unos cuadrangulares
# image content : None
# : u luego les cuento entonces , ahora me iré a hacer una natilla
# image content : None
# Ahi los dejo muchachos , no se me suiciden cara lanzando un beso
# image content : None
#
# Teniendo en cuenta que el usuario está deprimido, justifica los motivos de esto con base en sus publicaciones
#
#
# Si se tiene desactivada la descarga de archivos cualquiera podría entrar y denunciar sin tan siquiera llegar a ver algo , bueno digo en lo que sería telegram
# image content : None
# Chicos os imagináis haber estado siempre con estrés pero pasaba y luego a encontraros en una situación que no sabían explicar ? Así inicio mi depresión y ahora ansiedad generalizada , lo peor de todo es que mi pareja cree que la depresión y ansiedad es algo que se va diciendo “ no pienses en ello ” vivo en un pueblo donde ni me molesto en conocer gente porque cuando estuve estudiando mire más o menos con que tipo de gente podría rodearme y la verdad es que no me emociono absolutamente nada . Hoy día solo me queda hable a veces con algunos amigos de donde vengo y poco más .
# image content : None
# Me uní aquí para al menos interactuar con gente que sabe lo que siente y demás .
# image content : None
# Juegas online o algo ? Si es así igual podríamos jugar juntas y hablar un rato
# image content : None
# Me parece súper bien lo que dices , pero creo que este no es el lugar indicado para tus servicios , si alguien quiere y necesita ayuda la buscará , no vendrá “ la ayuda ” a buscar a nadie porque sinceramente lo que parecerá es que es un timo . Cada quien tiene sus batallas y decide como lucha con ellas . Yo me metí para interactuar a veces con personas con mis mismos problemas no para leer que alguien por 10 $ ya solucionará mis problemas , porque créeme , mis problemas solo los puedo solucionar yo misma , no porque tú me des un consejo y demás . Que no hago el comentario con mala intención , es solo que me da pereza estar leyendo aquí como si fuera milanuncios .
# image content : None
# No la conozco y lo que le sirva a ella no quiere decir que nos vaya a servir a todos . Simple opinión .
# image content : None
# Tío ... yo hablaba por mi no por ellos , creo que deberías aprender a leer , eso en primer lugar , en segundo si a alguien de aquí le interesara no estarías con la publicidad por segunda vez en el día , luego lo de que no quiero salir de mis problemas o demás , es mi problema y el de cada uno , ya con ese comentario se nota cuánto sabes de psicología , porque se lo que es ir ( en su día ) donde un psicólogo y nunca dirían algo como ello a algún paciente . Yo me medico y por eso no necesito ninguno . Suficiente tengo y tenemos con nuestras cosas para que vengas a decir que no queremos tratarnos o no , tu que sabes ? Mejor hablar poquito y no quedar como “ x ” persona por hablar de lo que no sabes .
# image content : None
# Pero quien es admin aquí ?
# image content : None
# Te escribí por privado
# image content : None
# No puedo con la gente que intenta llamar la atención de esa manera .
# image content : None
# Hay maneras de pedir ayuda y hay maneras de llamar la atención . Por muy mal que te encuentres pides ayuda no que alguien te ruegue que no te mates . Ves las diferencias ?
# image content : None
# Aparte que ya de por si somos de alguna manera negativos por algo y luego viene otro y te pone peor por decir esas cosas y demás .
# image content : None
# Yo he dicho todo esto porque el tío ese escribió lo que escribió , de haber escrito que se sentía mal o si había alguien con quien hablar el trato sería diferente .
# image content : None
# Cada persona sufre diferente aquí no hay una vara de medir , lo que yo sufra puede que otro lo tolere más que yo , es como lo siente la persona no la gravedad del asunto .
# image content : None
# Pues a la próxima solo di que vendrán momentos mejores y que trate de olvidar el asunto 5 min y no diciendo que sufre por una mierda y lo compares . Solo sabes como piensas y sientes tu , no los demás .
# image content : None
# Madre mía se supone que este grupo es para hacernos compañía cara de payaso
# image content : None
# Chicos os quería pedir un favor
# image content : None
# Mi chico recién empezó a trabajar en un taller como encargado de una parte que lo llevaba otro que se fue a otro taller y de repente hoy de la nada en las últimas 2 horas han dejado pésimas valoraciones de donde el trabaja , no se si quieren boicotear el otro que se fue o que , pero era para ver si podías ponerle 5 estrellas no hace falta dejar comentario . manos en oración
# image content : None
# No es necesario el móvil
# image content : None
# Ni registrarse ni nada
# image content : None
# Solo es poner las 5 estrellas
# image content : None
# Si alguien me quiere ayudar me avisa gracias
# image content : None
# Imagina que tu propósito en la vida sea que alguien te ame porque al parecer no sabes lo que es el amor propio y luego vienes a un grupo para interactuar y estar comunicado con personas con problemas similares a decir que te mataras para llamar la atención y te digan y rueguen que no lo hagas . cara de payaso
# image content : None
# Creí que este grupo era para hablar con personas no para llamar la atención de ese tipo de manera .
# image content : None
# Se de gente que se suicido porque así lo querían y no rogaron ni llamaron la atención antes de hacerlo .
# image content : None
# Admins creí que esto era para compartir , no ora rogar . Ya paso lo del chico y las paracetamol aquella vez . Vaya pereza .
# image content : None
# Yo solo decía , creí que aquella vez era regla general y aplicaba para todos . En fin me voy a comer . Que estén bien .
# image content : None
# Subnormal ? Para eso te dan las neuronas al atacar a alguien ? Mira chica estoy comiendo déjame hacer la digestión en paz . Si no te gusta pues apechuga y ya . Sabes lo que es la libre expresión ?
# image content : None
# Ay no me jodas , no se si fue Rojas u otro admin que la vez pasada un tío empezó a decir que con 20 paracetamol no se que y le dijimos que no llamara la atención de esa manera que esto era un grupo de ayuda no de estar rogando y suplicando para que no hagáis algo , una cosa es hablar de problemas para sentirse acompañado otro es decir me mato ahora ya vengo y luego decir tonteras . Yo por eso lo dije porque la otra vez quedó dicho que el grupo no era para eso , ahora , si no recordáis esa conversación pues ni estabais en el grupo y ya . Así que nadie sabe al parecer que se dijo ese día . cara sonriendo con ojos sonrientes
# image content : None
# Dije que no sabía si eras tú u otro .
# image content : None
# Contar tus problemas , pedir ayuda con algo botón de marca de verificación Venir a decir que te vas a tomar lejía u otra cosa o demás que atentarán a tu vida para llamar la atención y que te rueguen que no lo hagas marca de cruz ... Así de claro cara sonriendo con ojos sonrientes si es así hacerlo por privado con alguien del grupo que interactúes mucho , no todo el grupo quiere leer esas cosas .
# image content : None
# Ósea que os habéis metido aquí para que os roguemos que no atenten con sus vidas ?
# image content : None
# Es que al parecer ese el fin que tienen , no les basta con frases como “ mira las cosas de otra manera ” “ todo mejorará ” “ piensa en ti que vales ” ... es que quieren que les rueguen y demás para sentir que tienen la atención de esa persona y yo con eso ya no puedo , me cansa y me aburre . Muchas personas que se han suicidado nunca tuvieron alguien con quien hablar lo mínimo y si lo hicieron tampoco le dijeron ni avisaron a nadie , esas son las personas que de verdad no tenían ninguna vía de escape . El grupo en si está para hablar , escuchar y ayudarse si se puede . Si no lo ven como una vía de ayuda y solo quieren venir a que les rueguen la verdad no todo el grupo está para eso . Y si lo digo es porque puedo opinar y decir lo que quiera . En fin .
# image content : None
# Piensa que en el grupo hay personas que por muy mierda que lo pasan no pueden decir fácilmente que se matarán de “ x ” manera porque hay muchas cosas en lo que piensan como en su familia al enterarse de haberlo echo o demás cosas . Piensa que no todos queremos leer esas cosas . Piensa que simplemente es muy difícil de leer más cuando lo escriben tan fácilmente pero al final solo lo escriben por escribir algo . Entonces luego de haber pensado eso , te sigue ofendiendo ? Y si te ofende , no crees que en un grupo donde venimos algunos a mejorar el día o la vida misma llega alguien y escribe eso y no podemos sentirnos ofendidos nosotros también ?
# image content : None
# Creo que muchos no han entendido nada de lo que quise decir , hay maneras de decir las cosas y pedir ayuda . “ Me quiero morir ” “ me quiero morir no puedo con x situación ” “ me quiero morir porque me pasó “ x ” cosa ” son frases que se pueden decir y nadie dirá que quieres llamar la atención , sino que te ayudarían a ver las cosas de otras perspectivas la finalidad del grupo es ayudarse , la cosa viene cuando alguien pone “ busque x cosa en internet y si la hago estaré muerto en no se cuanto tiempo así que lo haré ” o cosas parecidas a como atentar contra la vida , así es como se llama la atención , para que diría alguien eso sino es para que le digan que no lo haga ? cara con monóculo conozco personas que son cero empaticas pero no por ello creería que son psicopatas , cada quien aguanta y ayuda de los demás lo que ellos quieren , no todos somos iguales . Leer bien lo que he puesto , no dije que se llama la atención así por así . cara sonriente cara sonriente cara sonriente
# image content : None
# Felicidad no se , estabilidad económica si y créeme que cuando te independizas eso es vital .
# image content : None
#
# Teniendo en cuenta que el usuario está deprimido, justifica los motivos de esto con base en sus publicaciones
#
#
# Tienen aquí alguien qué los ayude ?
# image content : None
# Termine una relación de cuatro años , llevo 5 días sin dormir
# image content : None
# Solo he pasado llorando todo este tiempo
# image content : None
# No sé cómo levantarme de la cama
# image content : None
# Siento que solo estoy cayendo en un abismo
# image content : None
# Estoy en la universidad y he pesado retirarme
# image content : None
# No , nunca la he tomado
# image content : None
# Mi mamá murió hacen casi 5 años
# image content : None
# No vivo con personas que me amén
# image content : None
# Mi hermana ya tiene su hogar , vive con su esposo
# image content : None
# Poco , por sus tiempos
# image content : None
# No tengo a donde ir
# image content : None
# Dependía mucho de mi expareja
# image content : None
# Y ahora no sé que hacer
# image content : None
# Quisiera por lo menos levantarme de la cama
# image content : None
# Solo quisiera empezar de cero
# image content : None
# Que podemos hacer cuando estamos en medio de una crisis ?
# image content : None
# Siento que el pecho late muy fuerte
# image content : None
#
# Teniendo en cuenta que el usuario está deprimido, justifica los motivos de esto con base en sus publicaciones
#
#
# No lo sé , solo no me siento bien
# image content : None
# Creo que es una mezcla de todo , era muy buena mi vida , tenía éxito profesional , sentimental
# image content : None
# A los 20 años ya era independiente , docente , a los 25 ya tenía una planta de personal de 10 empleados , mi exnovio era una persona reconocida y todo era como perfecto , mi primer y único jefe me hizo daño y eso me dificultaba encontrar pareja pero con mi ex novio solo fluía y el entendía mis miedos y esas cosas
# image content : None
# Pero desde junio del año pasado todo se desató , mis empleados dañaron bases de datos , se llevaron mis clientes y casi lo pierdo todo , llore mucho pero empecé a cogerle fastidio a mi trabajo , a las personas y solo me entendía con mi pareja
# image content : None
# Luego un día antes de mis cumpleaños me escribió que ya no quería nada
# image content : None
# Y pensé que estaba llevándolo con calma pero últimamente me dan muchas ganas de llorar , de correr , me Sudán las manos , ayer mi ex me escribió en la madrugada que fuera por el
# image content : None
# Fui , me sentí feliz
# image content : None
# Pero el simplemente me dejó plantada
# image content : None
# Nunca apareció y no se , solo no me siento bien , no me siento nada bien
# image content : None
# No se como explicarlo pero algo en mi no esta funcionando
# image content : None
# Busque un chat porque ni siquiera me gusta relacionarme con la gente mi entorno
# image content : None
# Te quiero agradecer mucho por tu respuesta inmediata esta mañana y por escucharme un rato . Aún no me siento bien y he tenido mucho vómito todo el día , pero si me siento un poco mejor .
# image content : None
# Perdón por la forma de entrar esta mañana al chat , mi nombre es Angela soy de Colombia y tengo 29 años
# image content : None
